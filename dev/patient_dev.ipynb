# %% [markdown]
# # Init

# %%
import os
os.chdir("..")

# %%
# src/tables/patient.py
import numpy as np
import pandas as pd
import duckdb
import logging
from importlib import reload
import src.utils
reload(src.utils)
from src.utils import construct_mapper_dict, load_mapping_csv, \
    rename_and_reorder_cols, save_to_rclif, setup_logging, mimic_table_pathfinder, \
    clif_table_pathfinder, read_from_rclif
# Out:
# loaded configuration from /Users/wliao0504/code/clif/CLIF-MIMIC/src/../config/config.json
# loaded configuration from /Users/wliao0504/code/clif/CLIF-MIMIC/src/../config/config.json

# %%
setup_logging()

PATIENT_COL_NAMES = [
    "patient_id", "race_name", "race_category", "ethnicity_name", "ethnicity_category",
    "sex_name", "sex_category", "birth_date", "death_dttm", "language_name", "language_category"
]
# Out:
# 2025-09-12 22:55:35,038 - INFO - initialized logging at logs/etl.log

# %%
race_ethnicity_mapping = load_mapping_csv("race_ethnicity")
race_mapper_dict = construct_mapper_dict(race_ethnicity_mapping, "mimic_race", "race")
ethnicity_mapper_dict = construct_mapper_dict(race_ethnicity_mapping, "mimic_race", "ethnicity")

# load mimic data
mimic_patients = pd.read_parquet(mimic_table_pathfinder("patients"))
mimic_admissions = pd.read_parquet(mimic_table_pathfinder("admissions"))

# %% [markdown]
# # ETL

# %% [markdown]
# ## language

# %%
language_df = pd.read_excel("data/data_models/language_category.1.xlsx")
language_df["language_category"].unique()

# %%
mimic_admissions.value_counts("language", dropna = False)
# Out:
# language
# English                   492316
# Spanish                    18303
# Russian                     8143
# Chinese                     7598
# Kabuverdianu                4801
# Portuguese                  2938
# Haitian                     2518
# Other                       1392
# Vietnamese                  1170
# Italian                     1000
# Modern Greek (1453-)         880
# NaN                          775
# Arabic                       676
# American Sign Language       522
# Persian                      454
# Polish                       417
# Korean                       360
# Thai                         288
# Khmer                        264
# Amharic                      254
# Hindi                        191
# French                       191
# Somali                       160
# Japanese                     158
# Bengali                      152
# Armenian                     107
# Name: count, dtype: int64

# %%
LANGUAGE_MAPPER = {
    'English': 'English', 
    'Spanish': 'Spanish', 
    'Russian': 'Russian', 
    'Chinese': 'Chinese', 
    'Kabuverdianu': 'Portuguese', 
    'Portuguese': 'Portuguese', 
    'Haitian': 'Haitian Creole', 
    'Other': 'Other and unspecified languages', 
    'Vietnamese': 'Vietnamese', 
    'Italian': 'Italian', 
    'Modern Greek (1453-)': 'Greek', 
    None: 'Unknown or NA',  # NOTE: test this 
    'Arabic': 'Arabic', 
    'American Sign Language': 'Sign Language', 
    'Persian': 'Persian', 
    'Polish': 'Polish', 
    'Korean': 'Korean', 
    'Thai': 'Thai, Lao, or other Tai-Kadai languages', 
    'Khmer': 'Khmer', 
    'Amharic': 'Amharic, Somali, or other Afro-Asiatic languages', 
    'Hindi': 'Hindi', 
    'French': 'French', 
    'Somali': 'Amharic, Somali, or other Afro-Asiatic languages', 
    'Japanese': 'Japanese', 
    'Bengali': 'Bengali', 
    'Armenian': 'Armenian'
}

# %% [markdown]
# test if conflicting language over multiple encounters

# %%
query = f"""
SELECT 
    subject_id as patient_id, 
    hadm_id as hospitalization_id,
    language as language_name,
    admittime as admittime
FROM '{mimic_table_pathfinder("admissions")}'
"""
df = duckdb.query(query).df()
df["language_category"] = df["language_name"].map(language_mapper)

# %% [markdown]
# the following show that the inconsistency would not be a concern:

# %%
query = """
SELECT 
    patient_id,
    FIRST(language_category) as language_category,
    COUNT(DISTINCT language_name) AS unique_lang_count,
FROM df
/* WHERE race_category NOT IN ('Other', 'Unknown') OR ethnicity_category NOT IN ('Other', 'Unknown') */
GROUP BY patient_id
-- HAVING unique_lang_count > 1
"""
df2 = duckdb.query(query).df()
df2.head()
# Out:
#    patient_id language_category  unique_lang_count
# 0    19374186           English                  1
# 1    19374315           English                  1
# 2    19374373           English                  1
# 3    19374379           English                  1
# 4    19374436           English                  1

# %%
df[df["language_name"].isna()]
# Out:
#         patient_id  hospitalization_id language_name           admittime  \
# 597       10010424            28388172          None 2164-05-27 17:47:00
# 2677      10049642            26714941          None 2177-02-20 03:15:00
# 2767      10051939            29623973          None 2112-05-29 15:48:00
# 3665      10071605            21911997          None 2156-08-17 20:17:00
# 5325      10107262            27069114          None 2158-04-18 01:22:00
# ...            ...                 ...           ...                 ...
# 543448    19952742            29264490          None 2149-10-12 12:00:00
# 545066    19984259            20109446          None 2153-11-29 23:43:00
# 545067    19984259            26619670          None 2154-01-28 21:29:00
# 545068    19984259            26869546          None 2153-12-09 21:06:00
# 545956    19998843            24842066          None 2187-02-05 09:27:00
#
#        language_category
# 597        Unknown or NA
# 2677       Unknown or NA
# 2767       Unknown or NA
# 3665       Unknown or NA
# 5325       Unknown or NA
# ...                  ...
# 543448     Unknown or NA
# 545066     Unknown or NA
# 545067     Unknown or NA
# 545068     Unknown or NA
# 545956     Unknown or NA
#
# [775 rows x 5 columns]

# %%
query = f"""
SELECT 
    subject_id as patient_id,
    FIRST(language) as language_name
FROM '{mimic_table_pathfinder("admissions")}'
GROUP BY subject_id
"""
df = duckdb.query(query).df()
df["language_category"] = df["language_name"].map(LANGUAGE_MAPPER)
df
# Out:
#         patient_id language_name language_category
# 0         19084358       English           English
# 1         19084360       English           English
# 2         19085455       English           English
# 3         19085662       English           English
# 4         19086156       Russian           Russian
# ...            ...           ...               ...
# 223447    19082444       English           English
# 223448    19082488       English           English
# 223449    19082696       English           English
# 223450    19083252       English           English
# 223451    19084226       English           English
#
# [223452 rows x 3 columns]

# %% [markdown]
# ## race and ethnicity

# %%
query = """
SELECT 
    subject_id as patient_id, 
    hadm_id as hospitalization_id,
    race as race_name, 
    race as ethnicity_name,
    admittime as admittime
FROM mimic_admissions
"""
race_ethn = duckdb.query(query).df()
race_ethn["race_category"] = race_ethn["race_name"].map(race_mapper_dict)
race_ethn["ethnicity_category"] = race_ethn["ethnicity_name"].map(ethnicity_mapper_dict)
query = """
SELECT 
    patient_id,
    hospitalization_id,
    race_name,
    race_category,
    ethnicity_name,
    ethnicity_category,
    admittime,
    CASE
        WHEN (race_category IN ('Other', 'Unknown')) AND (ethnicity_category IN ('Other', 'Unknown')) THEN 1
        ELSE 0
    END AS true_noninfo
FROM race_ethn
"""
race_ethn = duckdb.query(query).df()
race_ethn
# Out:
#         patient_id  hospitalization_id race_name race_category ethnicity_name  \
# 0         10000032            22595853     WHITE         White          WHITE
# 1         10000032            22841357     WHITE         White          WHITE
# 2         10000032            25742920     WHITE         White          WHITE
# 3         10000032            29079034     WHITE         White          WHITE
# 4         10000068            25022803     WHITE         White          WHITE
# ...            ...                 ...       ...           ...            ...
# 546023    19999828            25744818     WHITE         White          WHITE
# 546024    19999828            29734428     WHITE         White          WHITE
# 546025    19999840            21033226     WHITE         White          WHITE
# 546026    19999840            26071774     WHITE         White          WHITE
# 546027    19999987            23865745   UNKNOWN       Unknown        UNKNOWN
#
#        ethnicity_category           admittime  true_noninfo
# 0            Non-Hispanic 2180-05-06 22:23:00             0
# 1            Non-Hispanic 2180-06-26 18:27:00             0
# 2            Non-Hispanic 2180-08-05 23:44:00             0
# 3            Non-Hispanic 2180-07-23 12:35:00             0
# 4            Non-Hispanic 2160-03-03 23:16:00             0
# ...                   ...                 ...           ...
# 546023       Non-Hispanic 2149-01-08 16:44:00             0
# 546024       Non-Hispanic 2147-07-18 16:23:00             0
# 546025       Non-Hispanic 2164-09-10 13:47:00             0
# 546026       Non-Hispanic 2164-07-25 00:27:00             0
# 546027            Unknown 2145-11-02 21:38:00             1
#
# [546028 rows x 8 columns]

# %%
test_patient_ids = [10005236, 10016673, 10017492, 10006513, 10304619, 10617011, 10360391, 10375831,11066451]
race_ethn_test = race_ethn[race_ethn["patient_id"].isin(test_patient_ids)]
race_ethn_test
# Out:
#        patient_id  hospitalization_id                       race_name  \
# 324      10005236            23384508          WHITE - OTHER EUROPEAN
# 325      10005236            25656545                         UNKNOWN
# 412      10006513            28504108     HISPANIC/LATINO - DOMINICAN
# 413      10006513            29846618                           OTHER
# 955      10016673            29103261       HISPANIC/LATINO - MEXICAN
# 985      10017492            27417763      PATIENT DECLINED TO ANSWER
# 986      10017492            27672872      PATIENT DECLINED TO ANSWER
# 15902    10304619            21512114              HISPANIC OR LATINO
# 15903    10304619            23891877  HISPANIC/LATINO - PUERTO RICAN
# 15904    10304619            24179237  HISPANIC/LATINO - PUERTO RICAN
# 15905    10304619            26866149  HISPANIC/LATINO - PUERTO RICAN
# 15906    10304619            27163855  HISPANIC/LATINO - PUERTO RICAN
# 15907    10304619            27366580  HISPANIC/LATINO - PUERTO RICAN
# 15908    10304619            28790055  HISPANIC/LATINO - PUERTO RICAN
# 15909    10304619            29039369  HISPANIC/LATINO - PUERTO RICAN
# 18904    10360391            24477663                           WHITE
# 18905    10360391            27407931          BLACK/AFRICAN AMERICAN
# 18906    10360391            27877178          BLACK/AFRICAN AMERICAN
# 18907    10360391            29392694          BLACK/AFRICAN AMERICAN
# 19716    10375831            20892410            ASIAN - ASIAN INDIAN
# 19717    10375831            23595417            ASIAN - ASIAN INDIAN
# 19718    10375831            23860631                           OTHER
# 19719    10375831            29671280            ASIAN - ASIAN INDIAN
# 32604    10617011            23981516              HISPANIC OR LATINO
# 32605    10617011            28792406  HISPANIC/LATINO - PUERTO RICAN
# 56806    11066451            20396769                           WHITE
# 56807    11066451            25848946                         UNKNOWN
#
#                    race_category                  ethnicity_name  \
# 324                        White          WHITE - OTHER EUROPEAN
# 325                      Unknown                         UNKNOWN
# 412                        Other     HISPANIC/LATINO - DOMINICAN
# 413                        Other                           OTHER
# 955                        Other       HISPANIC/LATINO - MEXICAN
# 985                      Unknown      PATIENT DECLINED TO ANSWER
# 986                      Unknown      PATIENT DECLINED TO ANSWER
# 15902                      Other              HISPANIC OR LATINO
# 15903                      Other  HISPANIC/LATINO - PUERTO RICAN
# 15904                      Other  HISPANIC/LATINO - PUERTO RICAN
# 15905                      Other  HISPANIC/LATINO - PUERTO RICAN
# 15906                      Other  HISPANIC/LATINO - PUERTO RICAN
# 15907                      Other  HISPANIC/LATINO - PUERTO RICAN
# 15908                      Other  HISPANIC/LATINO - PUERTO RICAN
# 15909                      Other  HISPANIC/LATINO - PUERTO RICAN
# 18904                      White                           WHITE
# 18905  Black or African American          BLACK/AFRICAN AMERICAN
# 18906  Black or African American          BLACK/AFRICAN AMERICAN
# 18907  Black or African American          BLACK/AFRICAN AMERICAN
# 19716                      Asian            ASIAN - ASIAN INDIAN
# 19717                      Asian            ASIAN - ASIAN INDIAN
# 19718                      Other                           OTHER
# 19719                      Asian            ASIAN - ASIAN INDIAN
# 32604                      Other              HISPANIC OR LATINO
# 32605                      Other  HISPANIC/LATINO - PUERTO RICAN
# 56806                      White                           WHITE
# 56807                    Unknown                         UNKNOWN
#
#       ethnicity_category           admittime  true_noninfo
# 324         Non-Hispanic 2180-06-26 20:22:00             0
# 325              Unknown 2177-11-29 11:30:00             1
# 412             Hispanic 2125-05-06 11:22:00             0
# 413              Unknown 2127-03-27 14:52:00             1
# 955             Hispanic 2188-03-18 18:00:00             0
# 985              Unknown 2116-06-26 18:25:00             1
# 986              Unknown 2114-03-19 20:05:00             1
# 15902           Hispanic 2161-06-19 00:47:00             0
# 15903           Hispanic 2171-01-19 01:04:00             0
# 15904           Hispanic 2174-06-17 06:37:00             0
# 15905           Hispanic 2167-06-20 16:44:00             0
# 15906           Hispanic 2166-12-07 02:33:00             0
# 15907           Hispanic 2169-03-21 22:41:00             0
# 15908           Hispanic 2170-12-26 01:59:00             0
# 15909           Hispanic 2167-09-28 03:37:00             0
# 18904       Non-Hispanic 2194-04-20 07:15:00             0
# 18905       Non-Hispanic 2204-04-08 06:08:00             0
# 18906       Non-Hispanic 2203-05-04 13:20:00             0
# 18907       Non-Hispanic 2197-07-22 08:00:00             0
# 19716       Non-Hispanic 2134-07-02 17:48:00             0
# 19717       Non-Hispanic 2134-04-01 15:43:00             0
# 19718            Unknown 2130-01-01 16:58:00             1
# 19719       Non-Hispanic 2134-03-12 16:10:00             0
# 32604           Hispanic 2154-05-01 03:59:00             0
# 32605           Hispanic 2157-06-14 21:33:00             0
# 56806       Non-Hispanic 2191-11-19 14:32:00             0
# 56807            Unknown 2189-10-10 21:38:00             1

# %%
query = """
SELECT 
    patient_id, 
    race_name,
    race_category,
    ethnicity_name,
    ethnicity_category,
    COUNT(*) AS count,
    MAX(admittime) AS most_recent,
    true_noninfo,
    ROW_NUMBER() OVER (
        PARTITION BY patient_id 
        ORDER BY 
            count DESC, 
            true_noninfo,
            most_recent DESC
            ) 
        AS rn
FROM race_ethn_test
GROUP BY patient_id, race_name, race_category, ethnicity_name, ethnicity_category, true_noninfo
"""
race_ethn_ranked_test = duckdb.query(query).df()
race_ethn_ranked_test
# Out:
#     patient_id                       race_name              race_category  \
# 0     10360391          BLACK/AFRICAN AMERICAN  Black or African American
# 1     10360391                           WHITE                      White
# 2     10375831            ASIAN - ASIAN INDIAN                      Asian
# 3     10375831                           OTHER                      Other
# 4     11066451                           WHITE                      White
# 5     11066451                         UNKNOWN                    Unknown
# 6     10304619              HISPANIC OR LATINO                      Other
# 7     10617011  HISPANIC/LATINO - PUERTO RICAN                      Other
# 8     10617011              HISPANIC OR LATINO                      Other
# 9     10017492      PATIENT DECLINED TO ANSWER                    Unknown
# 10    10005236          WHITE - OTHER EUROPEAN                      White
# 11    10005236                         UNKNOWN                    Unknown
# 12    10016673       HISPANIC/LATINO - MEXICAN                      Other
# 13    10006513     HISPANIC/LATINO - DOMINICAN                      Other
# 14    10006513                           OTHER                      Other
# 15    10304619  HISPANIC/LATINO - PUERTO RICAN                      Other
#
#                     ethnicity_name ethnicity_category  count  \
# 0           BLACK/AFRICAN AMERICAN       Non-Hispanic      3
# 1                            WHITE       Non-Hispanic      1
# 2             ASIAN - ASIAN INDIAN       Non-Hispanic      3
# 3                            OTHER            Unknown      1
# 4                            WHITE       Non-Hispanic      1
# 5                          UNKNOWN            Unknown      1
# 6               HISPANIC OR LATINO           Hispanic      1
# 7   HISPANIC/LATINO - PUERTO RICAN           Hispanic      1
# 8               HISPANIC OR LATINO           Hispanic      1
# 9       PATIENT DECLINED TO ANSWER            Unknown      2
# 10          WHITE - OTHER EUROPEAN       Non-Hispanic      1
# 11                         UNKNOWN            Unknown      1
# 12       HISPANIC/LATINO - MEXICAN           Hispanic      1
# 13     HISPANIC/LATINO - DOMINICAN           Hispanic      1
# 14                           OTHER            Unknown      1
# 15  HISPANIC/LATINO - PUERTO RICAN           Hispanic      7
#
#            most_recent  true_noninfo  rn
# 0  2204-04-08 06:08:00             0   1
# 1  2194-04-20 07:15:00             0   2
# 2  2134-07-02 17:48:00             0   1
# 3  2130-01-01 16:58:00             1   2
# 4  2191-11-19 14:32:00             0   1
# 5  2189-10-10 21:38:00             1   2
# 6  2161-06-19 00:47:00             0   2
# 7  2157-06-14 21:33:00             0   1
# 8  2154-05-01 03:59:00             0   2
# 9  2116-06-26 18:25:00             1   1
# 10 2180-06-26 20:22:00             0   1
# 11 2177-11-29 11:30:00             1   2
# 12 2188-03-18 18:00:00             0   1
# 13 2125-05-06 11:22:00             0   1
# 14 2127-03-27 14:52:00             1   2
# 15 2174-06-17 06:37:00             0   1

# %%
query_new = """
SELECT 
    patient_id,
    race_name,
    race_category,
    ethnicity_name,
    ethnicity_category,
    rn
FROM race_ethn_ranked_test
WHERE rn = 1
"""
df2 = duckdb.query(query_new).df()
df2
# Out:
#    patient_id                       race_name              race_category  \
# 0    10360391          BLACK/AFRICAN AMERICAN  Black or African American
# 1    10375831            ASIAN - ASIAN INDIAN                      Asian
# 2    11066451                           WHITE                      White
# 3    10617011  HISPANIC/LATINO - PUERTO RICAN                      Other
# 4    10017492      PATIENT DECLINED TO ANSWER                    Unknown
# 5    10005236          WHITE - OTHER EUROPEAN                      White
# 6    10016673       HISPANIC/LATINO - MEXICAN                      Other
# 7    10006513     HISPANIC/LATINO - DOMINICAN                      Other
# 8    10304619  HISPANIC/LATINO - PUERTO RICAN                      Other
#
#                    ethnicity_name ethnicity_category  rn
# 0          BLACK/AFRICAN AMERICAN       Non-Hispanic   1
# 1            ASIAN - ASIAN INDIAN       Non-Hispanic   1
# 2                           WHITE       Non-Hispanic   1
# 3  HISPANIC/LATINO - PUERTO RICAN           Hispanic   1
# 4      PATIENT DECLINED TO ANSWER            Unknown   1
# 5          WHITE - OTHER EUROPEAN       Non-Hispanic   1
# 6       HISPANIC/LATINO - MEXICAN           Hispanic   1
# 7     HISPANIC/LATINO - DOMINICAN           Hispanic   1
# 8  HISPANIC/LATINO - PUERTO RICAN           Hispanic   1

# %% [markdown]
# ## death

# %%
q = f"""
SELECT DISTINCT subject_id
    , deathtime
    , dischtime
    , count: COUNT(*) OVER (PARTITION BY subject_id)
FROM '{mimic_table_pathfinder("admissions")}' a 
WHERE deathtime IS NOT NULL
ORDER BY count DESC
"""
death_from_admissions = duckdb.query(q).df()

q = f"""
FROM death_from_admissions a
FULL JOIN '{mimic_table_pathfinder("patients")}' p USING (subject_id)
SELECT DISTINCT ON (patient_id) patient_id: subject_id
    , adm_deathtime: deathtime
    , pt_dod: dod
    , adm_dischtime: dischtime
    , death_dttm: COALESCE(deathtime, dod)
    , count: COUNT(*) OVER (PARTITION BY subject_id)
WHERE death_dttm IS NOT NULL
-- sorted ascending by death_dttm allows us to keep the first (earliest) death via DISTINCT ON
-- which in MIMIC-IV 3.1 is only an issue that applies to one patient (who died twice)
ORDER BY count DESC, death_dttm
"""
death_joined = duckdb.query(q).df()

# %% [markdown]
# # Validate

# %%
mimic_patients
# Out:
#         subject_id gender  anchor_age  anchor_year anchor_year_group  \
# 0         10000032      F          52         2180       2014 - 2016
# 1         10000048      F          23         2126       2008 - 2010
# 2         10000058      F          33         2168       2020 - 2022
# 3         10000068      F          19         2160       2008 - 2010
# 4         10000084      M          72         2160       2017 - 2019
# ...            ...    ...         ...          ...               ...
# 364622    19999828      F          46         2147       2017 - 2019
# 364623    19999829      F          28         2186       2008 - 2010
# 364624    19999840      M          58         2164       2008 - 2010
# 364625    19999914      F          49         2158       2017 - 2019
# 364626    19999987      F          57         2145       2011 - 2013
#
#                dod
# 0       2180-09-09
# 1             None
# 2             None
# 3             None
# 4       2161-02-13
# ...            ...
# 364622        None
# 364623        None
# 364624  2164-09-17
# 364625        None
# 364626        None
#
# [364627 rows x 6 columns]

# %%
clif_patient = pd.read_parquet(clif_table_pathfinder("patient"))

# %%
clif_patient.value_counts(
    ["race_name", "race_category", "ethnicity_name", "ethnicity_category"],
    dropna = False
    )
# Out:
# race_name                                  race_category                              ethnicity_name                             ethnicity_category
# NaN                                        NaN                                        NaN                                        NaN                   141175
# WHITE                                      White                                      WHITE                                      Non-Hispanic          139118
# BLACK/AFRICAN AMERICAN                     Black or African American                  BLACK/AFRICAN AMERICAN                     Non-Hispanic           23552
# UNKNOWN                                    Unknown                                    UNKNOWN                                    Unknown                 9630
# OTHER                                      Other                                      OTHER                                      Unknown                 8754
# WHITE - OTHER EUROPEAN                     White                                      WHITE - OTHER EUROPEAN                     Non-Hispanic            5964
# ASIAN                                      Asian                                      ASIAN                                      Non-Hispanic            4253
# HISPANIC/LATINO - PUERTO RICAN             Other                                      HISPANIC/LATINO - PUERTO RICAN             Hispanic                3706
# ASIAN - CHINESE                            Asian                                      ASIAN - CHINESE                            Non-Hispanic            3480
# HISPANIC OR LATINO                         Other                                      HISPANIC OR LATINO                         Hispanic                3047
# UNABLE TO OBTAIN                           Unknown                                    UNABLE TO OBTAIN                           Unknown                 2460
# HISPANIC/LATINO - DOMINICAN                Other                                      HISPANIC/LATINO - DOMINICAN                Hispanic                2459
# BLACK/CAPE VERDEAN                         Black or African American                  BLACK/CAPE VERDEAN                         Non-Hispanic            2349
# WHITE - RUSSIAN                            White                                      WHITE - RUSSIAN                            Non-Hispanic            2161
# BLACK/CARIBBEAN ISLAND                     Black or African American                  BLACK/CARIBBEAN ISLAND                     Non-Hispanic            1552
# BLACK/AFRICAN                              Black or African American                  BLACK/AFRICAN                              Non-Hispanic            1499
# PATIENT DECLINED TO ANSWER                 Unknown                                    PATIENT DECLINED TO ANSWER                 Unknown                 1024
# ASIAN - SOUTH EAST ASIAN                   Asian                                      ASIAN - SOUTH EAST ASIAN                   Non-Hispanic             843
# ASIAN - ASIAN INDIAN                       Asian                                      ASIAN - ASIAN INDIAN                       Non-Hispanic             818
# HISPANIC/LATINO - GUATEMALAN               Other                                      HISPANIC/LATINO - GUATEMALAN               Hispanic                 763
# WHITE - EASTERN EUROPEAN                   White                                      WHITE - EASTERN EUROPEAN                   Non-Hispanic             742
# WHITE - BRAZILIAN                          White                                      WHITE - BRAZILIAN                          Non-Hispanic             724
# PORTUGUESE                                 White                                      PORTUGUESE                                 Non-Hispanic             708
# HISPANIC/LATINO - SALVADORAN               Other                                      HISPANIC/LATINO - SALVADORAN               Hispanic                 568
# AMERICAN INDIAN/ALASKA NATIVE              American Indian or Alaska Native           AMERICAN INDIAN/ALASKA NATIVE              Non-Hispanic             484
# HISPANIC/LATINO - MEXICAN                  Other                                      HISPANIC/LATINO - MEXICAN                  Hispanic                 462
# HISPANIC/LATINO - COLUMBIAN                Other                                      HISPANIC/LATINO - COLUMBIAN                Hispanic                 415
# SOUTH AMERICAN                             Other                                      SOUTH AMERICAN                             Unknown                  345
# ASIAN - KOREAN                             Asian                                      ASIAN - KOREAN                             Non-Hispanic             338
# HISPANIC/LATINO - HONDURAN                 Other                                      HISPANIC/LATINO - HONDURAN                 Hispanic                 276
# NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER  Native Hawaiian or Other Pacific Islander  NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER  Non-Hispanic             259
# MULTIPLE RACE/ETHNICITY                    Other                                      MULTIPLE RACE/ETHNICITY                    Unknown                  246
# HISPANIC/LATINO - CUBAN                    Other                                      HISPANIC/LATINO - CUBAN                    Hispanic                 229
# HISPANIC/LATINO - CENTRAL AMERICAN         Other                                      HISPANIC/LATINO - CENTRAL AMERICAN         Hispanic                 225
# Name: count, dtype: int64

# %%
mimic_admissions.value_counts("race", dropna = False)
# Out:
# race
# WHITE                                        336538
# BLACK/AFRICAN AMERICAN                        75482
# OTHER                                         19788
# WHITE - OTHER EUROPEAN                        13972
# UNKNOWN                                       13870
# HISPANIC/LATINO - PUERTO RICAN                10903
# HISPANIC OR LATINO                             8287
# ASIAN                                          7809
# ASIAN - CHINESE                                7644
# WHITE - RUSSIAN                                6597
# BLACK/CAPE VERDEAN                             6205
# HISPANIC/LATINO - DOMINICAN                    6070
# BLACK/CARIBBEAN ISLAND                         3875
# BLACK/AFRICAN                                  3495
# UNABLE TO OBTAIN                               3478
# PATIENT DECLINED TO ANSWER                     2162
# PORTUGUESE                                     2082
# ASIAN - SOUTH EAST ASIAN                       1973
# WHITE - EASTERN EUROPEAN                       1886
# HISPANIC/LATINO - GUATEMALAN                   1858
# ASIAN - ASIAN INDIAN                           1661
# WHITE - BRAZILIAN                              1526
# HISPANIC/LATINO - SALVADORAN                   1320
# AMERICAN INDIAN/ALASKA NATIVE                  1247
# HISPANIC/LATINO - COLUMBIAN                     920
# HISPANIC/LATINO - MEXICAN                       883
# SOUTH AMERICAN                                  774
# HISPANIC/LATINO - HONDURAN                      725
# ASIAN - KOREAN                                  664
# HISPANIC/LATINO - CUBAN                         641
# HISPANIC/LATINO - CENTRAL AMERICAN              603
# MULTIPLE RACE/ETHNICITY                         596
# NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER       494
# Name: count, dtype: int64

# %%
import src.tables.patient as patient
reload(patient)
# Out:
# 2025-05-12 12:41:07,766 - INFO - initialized logging at logs/etl.log
# <module 'src.tables.patient' from '/Users/wliao0504/code/clif/CLIF-MIMIC/src/tables/patient.py'>

# %%
out = patient._test()

# %%
patient._main()
# Out:
# 2025-05-12 12:41:10,806 - INFO - starting to build clif patient table --
# 2025-05-12 12:41:10,808 - INFO - initialized logging at logs/etl.log
# 2025-05-12 12:41:10,818 - INFO - fetching and processing the second component of the patient table: race and ethnicity data...
# 2025-05-12 12:41:11,068 - INFO - fetching and processing the first component of the patient table: sex/gender data...
# 2025-05-12 12:41:11,087 - INFO - fetching and processing the third component: death data...
# 2025-05-12 12:41:11,097 - INFO - fetching and processing the fourth component: language data...
# 2025-05-12 12:41:11,116 - INFO - merging the four components...
# 2025-05-12 12:41:11,335 - INFO - saving patient rclif table as a parquet file at /Users/wliao0504/code/clif/CLIF-MIMIC/src/../output/rclif-dev-test/clif_patient.parquet.
# 2025-05-12 12:41:11,439 - INFO - output saved to a parquet file, everything completed for the patient table!

# %%
clif_patient = read_from_rclif("patient")
clif_patient.head()
# Out:
#   patient_id                     race_name              race_category  \
# 0   18433744  HISPANIC/LATINO - SALVADORAN                      Other
# 1   18433796               WHITE - RUSSIAN                      White
# 2   18433806        BLACK/AFRICAN AMERICAN  Black or African American
# 3   18433819                         WHITE                      White
# 4   18433862                         WHITE                      White
#
#                  ethnicity_name ethnicity_category sex_name sex_category  \
# 0  HISPANIC/LATINO - SALVADORAN           Hispanic        M         Male
# 1               WHITE - RUSSIAN       Non-Hispanic        F       Female
# 2        BLACK/AFRICAN AMERICAN       Non-Hispanic        M         Male
# 3                         WHITE       Non-Hispanic        M         Male
# 4                         WHITE       Non-Hispanic        F       Female
#
#   birth_date death_dttm language_name language_category
# 0        NaT        NaT       Spanish           Spanish
# 1        NaT        NaT       English           English
# 2        NaT        NaT       English           English
# 3        NaT        NaT       English           English
# 4        NaT        NaT       English           English
