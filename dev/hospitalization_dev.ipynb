# %% [markdown]
# # Init

# %%
import os
os.chdir("..")
os.getcwd()
# Out:
# '/Users/wliao0504/code/clif/CLIF-MIMIC'

# %%
import numpy as np
import pandas as pd
import logging
import duckdb
import pandera as pa
from importlib import reload
import src.utils as utils
from typing import Dict, List
# reload(utils)
from src.utils import construct_mapper_dict, fetch_mimic_events, load_mapping_csv, \
    get_relevant_item_ids, find_duplicates, rename_and_reorder_cols, save_to_rclif, \
    convert_and_sort_datetime, setup_logging, con, REPO_ROOT, mimic_table_pathfinder, \
    search_mimic_items, read_from_rclif
from src.utils_qa import all_null_check
# Out:
# loaded configuration from /Users/wliao0504/code/clif/CLIF-MIMIC/src/../config/config.json

# %%
import src.tables.hospitalization as hospitalization
reload(hospitalization)
# Out:
# 2025-05-13 11:54:08,674 - INFO - initialized logging at logs/etl.log
# <module 'src.tables.hospitalization' from '/Users/wliao0504/code/clif/CLIF-MIMIC/src/tables/hospitalization.py'>

# %%
hospitalization._test()
# Out:
# 2025-05-13 11:54:09,901 - INFO - testing all...
# 2025-05-13 11:54:09,904 - INFO - initialized logging at logs/etl.log
# 2025-05-13 11:54:09,908 - INFO - extracting and mapping columns...
# 2025-05-13 11:54:10,029 - INFO - renaming and reordering columns...
# 2025-05-13 11:54:10,075 - INFO - recasting columns...
# {'schema_tested': True}
# {'schema_tested': True}

# %%
hospitalization._main()
# Out:
# 2025-05-13 11:56:21,908 - INFO - starting to build clif hospitalization table --
# 2025-05-13 11:56:21,910 - INFO - initialized logging at logs/etl.log
# 2025-05-13 11:56:21,914 - INFO - extracting and mapping columns...
# 2025-05-13 11:56:22,031 - INFO - renaming and reordering columns...
# 2025-05-13 11:56:22,076 - INFO - recasting columns...
# 2025-05-13 11:56:22,602 - INFO - saving to rclif...
# 2025-05-13 11:56:22,603 - INFO - saving hospitalization rclif table as a parquet file at /Users/wliao0504/code/clif/CLIF-MIMIC/src/../output/rclif-dev-test/clif_hospitalization.parquet.
# 2025-05-13 11:56:22,855 - INFO - output saved to a parquet file, everything completed for the hospitalization table!

# %%
clif_hosp = read_from_rclif("hospitalization")

# %%
clif_hosp
# Out:
#        patient_id hospitalization_id hospitalization_joined_id  \
# 0        19084296           27200634                      <NA>
# 1        19084324           20949393                      <NA>
# 2        19084324           22359158                      <NA>
# 3        19084324           24847843                      <NA>
# 4        19084324           28515743                      <NA>
# ...           ...                ...                       ...
# 546023   16842320           29198337                      <NA>
# 546024   16842478           25960343                      <NA>
# 546025   16842479           21189090                      <NA>
# 546026   16842479           27731842                      <NA>
# 546027   16842490           20999092                      <NA>
#
#                   admission_dttm            discharge_dttm  age_at_admission  \
# 0      2199-12-11 02:39:00+00:00 2199-12-11 15:12:00+00:00                38
# ...
