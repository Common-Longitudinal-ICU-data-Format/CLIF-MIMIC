# %% [markdown]
# This notebook replaces the continuous med-only notebook and now contains the development code for building both the continuous and intermittent med admin tables -- since they are sourced from the same MIMIC-IV table, `inputevents`.

# %% [markdown]
# # Init

# %%
import os
os.chdir("..")
os.getcwd()
# Out:
# '/Users/wliao0504/code/clif/CLIF-MIMIC'

# %% [markdown]
# ## Import

# %%
# src/tables/medication_admin.py
import numpy as np
import pandas as pd
import logging
from importlib import reload
import src.utils
reload(src.utils)
import duckdb
reload(duckdb)
from src.utils import construct_mapper_dict, fetch_mimic_events, load_mapping_csv, \
    get_relevant_item_ids, find_duplicates, rename_and_reorder_cols, save_to_rclif, \
    convert_and_sort_datetime, setup_logging, search_mimic_items
# from fuzzywuzzy import process
import src.tables.medication_admin as med
reload(med)
# Out:
# 2025-09-11 17:44:39,685 - INFO - initialized logging at logs/etl.log
# 2025-09-11 17:44:39,685 - INFO - initialized logging at logs/etl.log
# loaded configuration from /Users/wliao0504/code/clif/CLIF-MIMIC/src/../config/config.json
# loaded configuration from /Users/wliao0504/code/clif/CLIF-MIMIC/src/../config/config.json
# <module 'src.tables.medication_admin' from '/Users/wliao0504/code/clif/CLIF-MIMIC/src/tables/medication_admin.py'>

# %%
duckdb_version = duckdb.__version__
print(f"DuckDB version: {duckdb_version}")
# Out:
# DuckDB version: 1.3.2

# %%
setup_logging()

MAC_COLUMNS = [
    "hospitalization_id", "med_order_id", "admin_dttm", "med_name", "med_category", "med_group", 
    "med_route_name", "med_route_category", "med_dose", "med_dose_unit", "mar_action_name", "mar_action_category"
]

MAC_COL_RENAME_MAPPER = {
    "dose": "med_dose",
    "rateuom": "med_dose_unit",
    "amountuom": "med_dose_unit",
    "new_mar": "mar_action_name", 
    "linkorderid": "med_order_id",
    "recorded_dttm": "admin_dttm"
}

MAC_MCIDE_URL = "https://raw.githubusercontent.com/clif-consortium/CLIF/main/mCIDE/clif_medication_admin_continuous_med_categories.csv"

def map_name_to_category(name, categories):
    '''
    Map a medication name to a category using fuzzy matching.
    '''
    match, score = process.extractOne(name, categories)
    return match if score >= 80 else None

def are_doses_close(doses):
    return (abs(doses.iloc[0] - doses.iloc[1]) / max(doses.iloc[0], doses.iloc[1])) <= 0.1

# drop the row with the shorter mar_action_name
def drop_shorter_action_name(group):
    if len(group) == 2 and are_doses_close(group['med_dose']):
        return group.loc[[group['mar_action_name'].str.len().idxmax()]]
    return group
# Out:
# 2025-09-11 17:44:39,696 - INFO - initialized logging at logs/etl.log

# %%
pt_demo = pd.read_parquet('tests/clif_patient.parquet')

# %% [markdown]
# # Query MIMIC items

# %% [markdown]
# ## Intm

# %%
# Load medication categories from GitHub
intm_mcide_df = pd.read_csv("https://raw.githubusercontent.com/clif-consortium/CLIF/main/mCIDE/medication_admin_intermittent/clif_medication_admin_intermittent_med_categories.csv")

list_of_meds_to_query = intm_mcide_df.med_category.unique()

list_of_dfs = [search_mimic_items(med) for med in list_of_meds_to_query]

# Merge all dataframes on itemid
meds_found = pd.concat(list_of_dfs, ignore_index=True)
# Out:
# 2025-09-11 11:42:28,658 - INFO - searching for items with keyword 'acetaminophen' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:28,661 - INFO - identified 1 event tables to be separately queried: ['inputevents']
# 2025-09-11 11:42:28,807 - INFO - Found and concatenated 1 items from across 1 event table(s)
# 2025-09-11 11:42:28,807 - INFO - searching for items with keyword 'acyclovir' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:28,809 - INFO - identified 1 event tables to be separately queried: ['inputevents']
# 2025-09-11 11:42:28,897 - INFO - Found and concatenated 1 items from across 1 event table(s)
# 2025-09-11 11:42:28,898 - INFO - searching for items with keyword 'alteplase' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:28,900 - INFO - identified 1 event tables to be separately queried: ['inputevents']
# 2025-09-11 11:42:28,994 - INFO - Found and concatenated 1 items from across 1 event table(s)
# 2025-09-11 11:42:28,995 - INFO - searching for items with keyword 'amikacin' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:28,997 - INFO - identified 1 event tables to be separately queried: ['inputevents']
# 2025-09-11 11:42:29,071 - INFO - Found and concatenated 1 items from across 1 event table(s)
# 2025-09-11 11:42:29,072 - INFO - searching for items with keyword 'amoxicillin_clavulanate' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:29,074 - WARNING - No match for 'amoxicillin_clavulanate' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:29,074 - INFO - searching for items with keyword 'amphotericin_b' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:29,076 - INFO - identified 1 event tables to be separately queried: ['inputevents']
# 2025-09-11 11:42:29,140 - INFO - Found and concatenated 1 items from across 1 event table(s)
# 2025-09-11 11:42:29,140 - INFO - searching for items with keyword 'ampicillin_sulbactam' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:29,142 - INFO - identified 1 event tables to be separately queried: ['inputevents']
# 2025-09-11 11:42:29,230 - INFO - Found and concatenated 1 items from across 1 event table(s)
# 2025-09-11 11:42:29,230 - INFO - searching for items with keyword 'anakinra' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:29,232 - WARNING - No match for 'anakinra' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:29,232 - INFO - searching for items with keyword 'atracurium' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:29,234 - INFO - identified 2 event tables to be separately queried: ['chartevents', 'inputevents']
# 2025-09-11 11:42:30,071 - INFO - Found and concatenated 2 items from across 2 event table(s)
# 2025-09-11 11:42:30,072 - INFO - searching for items with keyword 'axicabtagene_ciloleucel' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:30,074 - WARNING - No match for 'axicabtagene_ciloleucel' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:30,074 - INFO - searching for items with keyword 'azithromycin' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:30,076 - INFO - identified 1 event tables to be separately queried: ['inputevents']
# 2025-09-11 11:42:30,171 - INFO - Found and concatenated 1 items from across 1 event table(s)
# 2025-09-11 11:42:30,172 - INFO - searching for items with keyword 'aztreonam' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:30,174 - INFO - identified 1 event tables to be separately queried: ['inputevents']
# 2025-09-11 11:42:30,260 - INFO - Found and concatenated 1 items from across 1 event table(s)
# 2025-09-11 11:42:30,261 - INFO - searching for items with keyword 'betamethasone' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:30,263 - WARNING - No match for 'betamethasone' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:30,263 - INFO - searching for items with keyword 'brexucabtagene_autoleucel' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:30,265 - WARNING - No match for 'brexucabtagene_autoleucel' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:30,265 - INFO - searching for items with keyword 'cefadroxil' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:30,267 - WARNING - No match for 'cefadroxil' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:30,267 - INFO - searching for items with keyword 'cefazolin' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:30,269 - INFO - identified 1 event tables to be separately queried: ['inputevents']
# 2025-09-11 11:42:30,370 - INFO - Found and concatenated 1 items from across 1 event table(s)
# 2025-09-11 11:42:30,370 - INFO - searching for items with keyword 'cefdinir' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:30,372 - WARNING - No match for 'cefdinir' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:30,372 - INFO - searching for items with keyword 'cefepime' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:30,374 - INFO - identified 1 event tables to be separately queried: ['inputevents']
# 2025-09-11 11:42:30,477 - INFO - Found and concatenated 1 items from across 1 event table(s)
# 2025-09-11 11:42:30,477 - INFO - searching for items with keyword 'cefiderocol' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:30,479 - WARNING - No match for 'cefiderocol' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:30,479 - INFO - searching for items with keyword 'cefixime' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:30,481 - WARNING - No match for 'cefixime' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:30,481 - INFO - searching for items with keyword 'cefotaxime' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:30,483 - WARNING - No match for 'cefotaxime' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:30,483 - INFO - searching for items with keyword 'cefotetan' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:30,484 - WARNING - No match for 'cefotetan' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:30,485 - INFO - searching for items with keyword 'cefoxitin' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:30,486 - WARNING - No match for 'cefoxitin' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:30,487 - INFO - searching for items with keyword 'ceftaroline' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:30,488 - INFO - identified 1 event tables to be separately queried: ['inputevents']
# 2025-09-11 11:42:30,566 - INFO - Found and concatenated 1 items from across 1 event table(s)
# 2025-09-11 11:42:30,566 - INFO - searching for items with keyword 'ceftazidime' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:30,568 - INFO - identified 1 event tables to be separately queried: ['inputevents']
# 2025-09-11 11:42:30,667 - INFO - Found and concatenated 1 items from across 1 event table(s)
# 2025-09-11 11:42:30,667 - INFO - searching for items with keyword 'ceftazidime_avibactam' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:30,669 - WARNING - No match for 'ceftazidime_avibactam' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:30,669 - INFO - searching for items with keyword 'ceftazidime_clavulanate' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:30,671 - WARNING - No match for 'ceftazidime_clavulanate' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:30,671 - INFO - searching for items with keyword 'ceftolozane_tazobactam' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:30,672 - WARNING - No match for 'ceftolozane_tazobactam' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:30,673 - INFO - searching for items with keyword 'ceftriaxone' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:30,675 - INFO - identified 1 event tables to be separately queried: ['inputevents']
# 2025-09-11 11:42:30,774 - INFO - Found and concatenated 1 items from across 1 event table(s)
# 2025-09-11 11:42:30,774 - INFO - searching for items with keyword 'cefuroxime' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:30,776 - WARNING - No match for 'cefuroxime' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:30,776 - INFO - searching for items with keyword 'cephalexin' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:30,778 - WARNING - No match for 'cephalexin' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:30,778 - INFO - searching for items with keyword 'chloramphenicol' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:30,780 - INFO - identified 1 event tables to be separately queried: ['inputevents']
# 2025-09-11 11:42:30,845 - INFO - Found and concatenated 1 items from across 1 event table(s)
# 2025-09-11 11:42:30,846 - INFO - searching for items with keyword 'ciltacabtagene_autoleucel' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:30,848 - WARNING - No match for 'ciltacabtagene_autoleucel' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:30,848 - INFO - searching for items with keyword 'ciprofloxacin' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:30,850 - INFO - identified 1 event tables to be separately queried: ['inputevents']
# 2025-09-11 11:42:30,942 - INFO - Found and concatenated 1 items from across 1 event table(s)
# 2025-09-11 11:42:30,943 - INFO - searching for items with keyword 'cisatracurium' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:30,945 - INFO - identified 1 event tables to be separately queried: ['inputevents']
# 2025-09-11 11:42:31,044 - INFO - Found and concatenated 1 items from across 1 event table(s)
# 2025-09-11 11:42:31,044 - INFO - searching for items with keyword 'clarithromycin' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:31,046 - WARNING - No match for 'clarithromycin' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:31,046 - INFO - searching for items with keyword 'clindamycin' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:31,048 - INFO - identified 1 event tables to be separately queried: ['inputevents']
# 2025-09-11 11:42:31,135 - INFO - Found and concatenated 1 items from across 1 event table(s)
# 2025-09-11 11:42:31,136 - INFO - searching for items with keyword 'colistin' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:31,137 - INFO - identified 1 event tables to be separately queried: ['inputevents']
# 2025-09-11 11:42:31,208 - INFO - Found and concatenated 1 items from across 1 event table(s)
# 2025-09-11 11:42:31,208 - INFO - searching for items with keyword 'fludrocoritisone' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:31,210 - WARNING - No match for 'fludrocoritisone' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:31,210 - INFO - searching for items with keyword 'daptomycin' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:31,212 - INFO - identified 1 event tables to be separately queried: ['inputevents']
# 2025-09-11 11:42:31,295 - INFO - Found and concatenated 1 items from across 1 event table(s)
# 2025-09-11 11:42:31,296 - INFO - searching for items with keyword 'dexamethasone' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:31,297 - WARNING - No match for 'dexamethasone' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:31,297 - INFO - searching for items with keyword 'diazepam ' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:31,299 - INFO - identified 1 event tables to be separately queried: ['inputevents']
# 2025-09-11 11:42:31,379 - INFO - Found and concatenated 1 items from across 1 event table(s)
# 2025-09-11 11:42:31,380 - INFO - searching for items with keyword 'dicloxacillin' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:31,381 - WARNING - No match for 'dicloxacillin' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:31,381 - INFO - searching for items with keyword 'diphenhydramine ' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:31,383 - WARNING - No match for 'diphenhydramine ' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:31,383 - INFO - searching for items with keyword 'doripenem' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:31,384 - WARNING - No match for 'doripenem' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:31,384 - INFO - searching for items with keyword 'dornase_alfa' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:31,386 - WARNING - No match for 'dornase_alfa' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:31,386 - INFO - searching for items with keyword 'doxycycline' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:31,387 - INFO - identified 1 event tables to be separately queried: ['inputevents']
# 2025-09-11 11:42:31,467 - INFO - Found and concatenated 1 items from across 1 event table(s)
# 2025-09-11 11:42:31,467 - INFO - searching for items with keyword 'ertapenem' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:31,469 - INFO - identified 1 event tables to be separately queried: ['inputevents']
# 2025-09-11 11:42:31,546 - INFO - Found and concatenated 1 items from across 1 event table(s)
# 2025-09-11 11:42:31,546 - INFO - searching for items with keyword 'erythromycin' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:31,548 - INFO - identified 1 event tables to be separately queried: ['inputevents']
# 2025-09-11 11:42:31,630 - INFO - Found and concatenated 1 items from across 1 event table(s)
# 2025-09-11 11:42:31,631 - INFO - searching for items with keyword 'etomidate ' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:31,632 - INFO - identified 1 event tables to be separately queried: ['chartevents']
# 2025-09-11 11:42:32,101 - INFO - Found and concatenated 1 items from across 1 event table(s)
# 2025-09-11 11:42:32,101 - INFO - searching for items with keyword 'fentanyl ' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:32,104 - INFO - identified 1 event tables to be separately queried: ['inputevents']
# 2025-09-11 11:42:32,216 - INFO - Found and concatenated 2 items from across 1 event table(s)
# 2025-09-11 11:42:32,216 - INFO - searching for items with keyword 'fidaxomicin' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:32,218 - WARNING - No match for 'fidaxomicin' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:32,218 - INFO - searching for items with keyword 'fluconazole' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:32,220 - INFO - identified 1 event tables to be separately queried: ['inputevents']
# 2025-09-11 11:42:32,326 - INFO - Found and concatenated 1 items from across 1 event table(s)
# 2025-09-11 11:42:32,326 - INFO - searching for items with keyword 'fosfomycin' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:32,328 - WARNING - No match for 'fosfomycin' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:32,328 - INFO - searching for items with keyword 'gentamicin' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:32,330 - INFO - identified 2 event tables to be separately queried: ['chartevents', 'inputevents']
# 2025-09-11 11:42:33,266 - INFO - Found and concatenated 7 items from across 2 event table(s)
# 2025-09-11 11:42:33,266 - INFO - searching for items with keyword 'haloperidol ' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:33,268 - INFO - identified 1 event tables to be separately queried: ['inputevents']
# 2025-09-11 11:42:33,355 - INFO - Found and concatenated 1 items from across 1 event table(s)
# 2025-09-11 11:42:33,356 - INFO - searching for items with keyword 'hydrocodone_acetaminophen ' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:33,357 - WARNING - No match for 'hydrocodone_acetaminophen ' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:33,358 - INFO - searching for items with keyword 'hydrocortisone' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:33,359 - WARNING - No match for 'hydrocortisone' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:33,359 - INFO - searching for items with keyword 'hydromorphone ' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:33,361 - INFO - identified 1 event tables to be separately queried: ['inputevents']
# 2025-09-11 11:42:33,466 - INFO - Found and concatenated 1 items from across 1 event table(s)
# 2025-09-11 11:42:33,466 - INFO - searching for items with keyword 'hydroxocobalamin' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:33,468 - WARNING - No match for 'hydroxocobalamin' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:33,468 - INFO - searching for items with keyword 'idecabtagene_vicleucel' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:33,470 - WARNING - No match for 'idecabtagene_vicleucel' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:33,470 - INFO - searching for items with keyword 'imipenem' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:33,472 - INFO - identified 1 event tables to be separately queried: ['inputevents']
# 2025-09-11 11:42:33,555 - INFO - Found and concatenated 1 items from across 1 event table(s)
# 2025-09-11 11:42:33,555 - INFO - searching for items with keyword 'isavuconazole' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:33,557 - WARNING - No match for 'isavuconazole' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:33,557 - INFO - searching for items with keyword 'itraconazole' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:33,559 - WARNING - No match for 'itraconazole' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:33,559 - INFO - searching for items with keyword 'ketamine ' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:33,561 - INFO - identified 1 event tables to be separately queried: ['chartevents']
# 2025-09-11 11:42:34,046 - INFO - Found and concatenated 1 items from across 1 event table(s)
# 2025-09-11 11:42:34,047 - INFO - searching for items with keyword 'levofloxacin' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:34,049 - INFO - identified 1 event tables to be separately queried: ['inputevents']
# 2025-09-11 11:42:34,145 - INFO - Found and concatenated 1 items from across 1 event table(s)
# 2025-09-11 11:42:34,146 - INFO - searching for items with keyword 'linezolid' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:34,148 - INFO - identified 1 event tables to be separately queried: ['inputevents']
# 2025-09-11 11:42:34,237 - INFO - Found and concatenated 1 items from across 1 event table(s)
# 2025-09-11 11:42:34,237 - INFO - searching for items with keyword 'lisocabtagene_maraleucel' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:34,239 - WARNING - No match for 'lisocabtagene_maraleucel' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:34,239 - INFO - searching for items with keyword 'lorazepam ' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:34,241 - INFO - identified 1 event tables to be separately queried: ['inputevents']
# 2025-09-11 11:42:34,341 - INFO - Found and concatenated 1 items from across 1 event table(s)
# 2025-09-11 11:42:34,342 - INFO - searching for items with keyword 'meropenem' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:34,343 - INFO - identified 1 event tables to be separately queried: ['inputevents']
# 2025-09-11 11:42:34,443 - INFO - Found and concatenated 1 items from across 1 event table(s)
# 2025-09-11 11:42:34,443 - INFO - searching for items with keyword 'meropenem_vaborbactam' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:34,445 - WARNING - No match for 'meropenem_vaborbactam' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:34,445 - INFO - searching for items with keyword 'methylene_blue' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:34,447 - WARNING - No match for 'methylene_blue' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:34,447 - INFO - searching for items with keyword 'methylprednisolone' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:34,448 - WARNING - No match for 'methylprednisolone' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:34,448 - INFO - searching for items with keyword 'metronidazole' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:34,450 - INFO - identified 1 event tables to be separately queried: ['inputevents']
# 2025-09-11 11:42:34,555 - INFO - Found and concatenated 1 items from across 1 event table(s)
# 2025-09-11 11:42:34,556 - INFO - searching for items with keyword 'micafungin' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:34,558 - INFO - identified 1 event tables to be separately queried: ['inputevents']
# 2025-09-11 11:42:34,664 - INFO - Found and concatenated 1 items from across 1 event table(s)
# 2025-09-11 11:42:34,665 - INFO - searching for items with keyword 'midazolam ' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:34,667 - INFO - identified 1 event tables to be separately queried: ['inputevents']
# 2025-09-11 11:42:34,781 - INFO - Found and concatenated 1 items from across 1 event table(s)
# 2025-09-11 11:42:34,781 - INFO - searching for items with keyword 'morphine ' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:34,783 - INFO - identified 1 event tables to be separately queried: ['inputevents']
# 2025-09-11 11:42:34,892 - INFO - Found and concatenated 1 items from across 1 event table(s)
# 2025-09-11 11:42:34,892 - INFO - searching for items with keyword 'moxifloxacin' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:34,894 - INFO - identified 1 event tables to be separately queried: ['inputevents']
# 2025-09-11 11:42:34,973 - INFO - Found and concatenated 1 items from across 1 event table(s)
# 2025-09-11 11:42:34,974 - INFO - searching for items with keyword 'nitrofurantoin' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:34,976 - WARNING - No match for 'nitrofurantoin' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:34,976 - INFO - searching for items with keyword 'nystatin' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:34,977 - WARNING - No match for 'nystatin' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:34,977 - INFO - searching for items with keyword 'olanzapine ' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:34,979 - WARNING - No match for 'olanzapine ' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:34,979 - INFO - searching for items with keyword 'oseltamivir' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:34,980 - WARNING - No match for 'oseltamivir' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:34,981 - INFO - searching for items with keyword 'oxacillin' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:34,982 - INFO - identified 1 event tables to be separately queried: ['inputevents']
# 2025-09-11 11:42:35,051 - INFO - Found and concatenated 1 items from across 1 event table(s)
# 2025-09-11 11:42:35,051 - INFO - searching for items with keyword 'oxycodone ' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:35,053 - WARNING - No match for 'oxycodone ' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:35,053 - INFO - searching for items with keyword 'oxycodone_acetaminophen ' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:35,054 - WARNING - No match for 'oxycodone_acetaminophen ' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:35,055 - INFO - searching for items with keyword 'penicillin' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:35,056 - INFO - identified 1 event tables to be separately queried: ['inputevents']
# 2025-09-11 11:42:35,137 - INFO - Found and concatenated 1 items from across 1 event table(s)
# 2025-09-11 11:42:35,138 - INFO - searching for items with keyword 'piperacillin_tazobactam' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:35,140 - INFO - identified 1 event tables to be separately queried: ['inputevents']
# 2025-09-11 11:42:35,239 - INFO - Found and concatenated 1 items from across 1 event table(s)
# 2025-09-11 11:42:35,239 - INFO - searching for items with keyword 'polymyxin_b' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:35,241 - WARNING - No match for 'polymyxin_b' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:35,241 - INFO - searching for items with keyword 'posaconazole' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:35,243 - WARNING - No match for 'posaconazole' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:35,243 - INFO - searching for items with keyword 'prednisolone' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:35,244 - WARNING - No match for 'prednisolone' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:35,245 - INFO - searching for items with keyword 'prednisone' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:35,246 - WARNING - No match for 'prednisone' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:35,246 - INFO - searching for items with keyword 'promethazine ' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:35,248 - WARNING - No match for 'promethazine ' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:35,248 - INFO - searching for items with keyword 'propofol ' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:35,250 - INFO - identified 2 event tables to be separately queried: ['chartevents', 'ingredientevents']
# 2025-09-11 11:42:35,802 - INFO - Found and concatenated 2 items from across 2 event table(s)
# 2025-09-11 11:42:35,802 - INFO - searching for items with keyword 'quetiapine' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:35,804 - WARNING - No match for 'quetiapine' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:35,804 - INFO - searching for items with keyword 'ribavirin' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:35,806 - INFO - identified 1 event tables to be separately queried: ['inputevents']
# 2025-09-11 11:42:35,873 - INFO - Found and concatenated 1 items from across 1 event table(s)
# 2025-09-11 11:42:35,873 - INFO - searching for items with keyword 'risperidone ' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:35,875 - WARNING - No match for 'risperidone ' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:35,875 - INFO - searching for items with keyword 'rocuronium' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:35,877 - INFO - identified 2 event tables to be separately queried: ['chartevents', 'inputevents']
# 2025-09-11 11:42:36,753 - INFO - Found and concatenated 2 items from across 2 event table(s)
# 2025-09-11 11:42:36,754 - INFO - searching for items with keyword 'streptomycin' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:36,755 - WARNING - No match for 'streptomycin' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:36,756 - INFO - searching for items with keyword 'succinylcholine' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:36,757 - WARNING - No match for 'succinylcholine' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:36,757 - INFO - searching for items with keyword 'sulfamethoxazole' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:36,759 - WARNING - No match for 'sulfamethoxazole' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:36,759 - INFO - searching for items with keyword 'tetracycline' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:36,761 - WARNING - No match for 'tetracycline' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:36,761 - INFO - searching for items with keyword 'ticarcillin_clavulanate' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:36,763 - WARNING - No match for 'ticarcillin_clavulanate' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:36,763 - INFO - searching for items with keyword 'tigecycline' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:36,765 - INFO - identified 1 event tables to be separately queried: ['inputevents']
# 2025-09-11 11:42:36,840 - INFO - Found and concatenated 1 items from across 1 event table(s)
# 2025-09-11 11:42:36,841 - INFO - searching for items with keyword 'tisagenlecleucel' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:36,843 - WARNING - No match for 'tisagenlecleucel' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:36,843 - INFO - searching for items with keyword 'tobramycin' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:36,845 - INFO - identified 2 event tables to be separately queried: ['chartevents', 'inputevents']
# 2025-09-11 11:42:37,897 - INFO - Found and concatenated 7 items from across 2 event table(s)
# 2025-09-11 11:42:37,898 - INFO - searching for items with keyword 'tocilizumab' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:37,899 - WARNING - No match for 'tocilizumab' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:37,900 - INFO - searching for items with keyword 'trimethoprim' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:37,901 - WARNING - No match for 'trimethoprim' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:37,902 - INFO - searching for items with keyword 'trimethoprim_sulfamethoxazole' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:37,904 - WARNING - No match for 'trimethoprim_sulfamethoxazole' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:37,904 - INFO - searching for items with keyword 'valacyclovir' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:37,905 - WARNING - No match for 'valacyclovir' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:37,905 - INFO - searching for items with keyword 'valganciclovir' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:37,907 - WARNING - No match for 'valganciclovir' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:37,907 - INFO - searching for items with keyword 'valproate ' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:37,909 - WARNING - No match for 'valproate ' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:37,909 - INFO - searching for items with keyword 'vancomycin' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:37,911 - INFO - identified 2 event tables to be separately queried: ['chartevents', 'inputevents']
# 2025-09-11 11:42:39,025 - INFO - Found and concatenated 7 items from across 2 event table(s)
# 2025-09-11 11:42:39,025 - INFO - searching for items with keyword 'vecuronium' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:39,027 - INFO - identified 2 event tables to be separately queried: ['chartevents', 'inputevents']
# 2025-09-11 11:42:39,646 - INFO - Found and concatenated 2 items from across 2 event table(s)
# 2025-09-11 11:42:39,646 - INFO - searching for items with keyword 'voriconazole' in column 'label' with case sensitive = False.
# 2025-09-11 11:42:39,648 - INFO - identified 1 event tables to be separately queried: ['inputevents']
# 2025-09-11 11:42:39,733 - INFO - Found and concatenated 1 items from across 1 event table(s)

# %%
# manually check some
df = search_mimic_items("plasma")
df
# Out:
# 2025-09-11 17:06:47,258 - INFO - searching for items with keyword 'plasma' in column 'label' with case sensitive = False.
# 2025-09-11 17:06:47,264 - INFO - identified 2 event tables to be separately queried: ['inputevents', 'procedureevents']
# 2025-09-11 17:06:47,619 - INFO - Found and concatenated 4 items from across 2 event table(s)
#        kw  itemid                                              label  \
# 0  plasma  220970                                Fresh Frozen Plasma
# 0  plasma  227551                                   Plasma Pheresis.
# 1  plasma  227532                                    Plasma Pheresis
# 2  plasma  220971  ESDEP (Solvent / Detergent Virus-Inactivated P...
#
#        abbreviation          linksto                     category unitname  \
# 0               FFP      inputevents      Blood Products/Colloids       mL
# 0  Plasma Pheresis.  procedureevents                 4-Procedures     None
# 1   Plasma Pheresis      inputevents      Blood Products/Colloids       mL
# 2             ESDEP      inputevents  Fluids - Other (Not In Use)       mL
#
#   param_type  count                                    value_instances  \
# 0   Solution  18828  Rate: 0.84, 318.0, 35640.0; Amount: 0.14, 300....
# 0  Processes    330  Min: 0.05416666666666667, Mean: 700.66, Max: 1...
# 1   Solution    146  Rate: 20.13, 386.5, 2093.33; Amount: 19.0, 299...
# 2   Solution      1                           Rate: , , ; Amount: , ,
#
#   amountuom_instances           rateuom_instances ordercategoryname_instances  \
# 0           mL: 18828  mL/hour: 18797, mL/min: 31    07-Blood Products: 18828
# 0                 NaN                         NaN                         NaN
# 1             mL: 146     mL/hour: 143, mL/min: 3      07-Blood Products: 146
# 2                None                        None                        None
#
#   secondaryordercategoryname_instances ordercategorydescription_instances
# 0                                 None               Continuous IV: 18828
# 0                                  NaN                                NaN
# 1                                 None                 Continuous IV: 146
# 2                                 None                               None

# %% [markdown]
# ## Cont

# %%
med_admin_mapping = load_mapping_csv("med_admin")
current_meds = med_admin_mapping['med_category'].unique()
latest_cont_meds = pd.read_csv("https://raw.githubusercontent.com/Common-Longitudinal-ICU-data-Format/CLIF/refs/heads/main/mCIDE/medication_admin_continuous/clif_medication_admin_continuous_med_categories.csv")
new_cont_meds = set(latest_cont_meds.med_category.unique()) - set(current_meds)
new_cont_meds
# Out:
# {'albumin_infusion',
#  'albuterol',
#  'alprostadil',
#  'baclofen',
#  'bivalirudin',
#  'bupivacaine',
#  'cangrelor',
#  'cosyntropin',
#  'dextrose_in_water_d5w',
#  'ipratropium',
#  'isoproterenol',
#  'lactated_ringers_solution',
#  'liothyronine',
#  'nitric_oxide',
#  'nitroglycerin',
#  'oxytocin',
#  'papaverine',
#  'phentolamine',
#  'pitocin',
#  'plasma_lyte',
#  'remifentanil',
#  'repletion',
#  'ropivacaine',
#  'sodium chloride',
#  'tacrolimus',
#  'terbutaline',
#  'thyroid replacement',
#  'tocolyttics',
#  'torsemide',
#  'zidovudine'}

# %%
list_of_dfs_cont = [search_mimic_items(med) for med in new_cont_meds]

# Merge all dataframes on itemid
cont_meds_found = pd.concat(list_of_dfs_cont, ignore_index=True)
# Out:
# 2025-09-11 16:02:54,107 - INFO - searching for items with keyword 'terbutaline' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:54,111 - WARNING - No match for 'terbutaline' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:54,112 - INFO - searching for items with keyword 'zidovudine' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:54,114 - WARNING - No match for 'zidovudine' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:54,114 - INFO - searching for items with keyword 'tocolyttics' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:54,116 - WARNING - No match for 'tocolyttics' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:54,116 - INFO - searching for items with keyword 'cangrelor' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:54,118 - WARNING - No match for 'cangrelor' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:54,119 - INFO - searching for items with keyword 'dextrose_in_water_d5w' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:54,121 - WARNING - No match for 'dextrose_in_water_d5w' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:54,121 - INFO - searching for items with keyword 'ropivacaine' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:54,123 - WARNING - No match for 'ropivacaine' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:54,124 - INFO - searching for items with keyword 'nitroglycerin' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:54,126 - INFO - identified 1 event tables to be separately queried: ['inputevents']
# 2025-09-11 16:02:54,285 - INFO - Found and concatenated 1 items from across 1 event table(s)
# 2025-09-11 16:02:54,286 - INFO - searching for items with keyword 'bivalirudin' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:54,287 - INFO - identified 1 event tables to be separately queried: ['inputevents']
# 2025-09-11 16:02:54,405 - INFO - Found and concatenated 2 items from across 1 event table(s)
# 2025-09-11 16:02:54,405 - INFO - searching for items with keyword 'thyroid replacement' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:54,407 - WARNING - No match for 'thyroid replacement' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:54,408 - INFO - searching for items with keyword 'baclofen' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:54,409 - WARNING - No match for 'baclofen' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:54,409 - INFO - searching for items with keyword 'torsemide' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:54,411 - WARNING - No match for 'torsemide' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:54,411 - INFO - searching for items with keyword 'nitric_oxide' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:54,413 - INFO - identified 1 event tables to be separately queried: ['chartevents']
# 2025-09-11 16:02:55,147 - INFO - Found and concatenated 2 items from across 1 event table(s)
# 2025-09-11 16:02:55,147 - INFO - searching for items with keyword 'cosyntropin' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:55,149 - WARNING - No match for 'cosyntropin' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:55,149 - INFO - searching for items with keyword 'oxytocin' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:55,151 - WARNING - No match for 'oxytocin' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:55,151 - INFO - searching for items with keyword 'albumin_infusion' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:55,152 - WARNING - No match for 'albumin_infusion' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:55,152 - INFO - searching for items with keyword 'albuterol' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:55,154 - WARNING - No match for 'albuterol' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:55,154 - INFO - searching for items with keyword 'tacrolimus' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:55,156 - WARNING - No match for 'tacrolimus' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:55,156 - INFO - searching for items with keyword 'lactated_ringers_solution' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:55,158 - WARNING - No match for 'lactated_ringers_solution' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:55,158 - INFO - searching for items with keyword 'alprostadil' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:55,159 - WARNING - No match for 'alprostadil' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:55,159 - INFO - searching for items with keyword 'phentolamine' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:55,161 - WARNING - No match for 'phentolamine' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:55,161 - INFO - searching for items with keyword 'ipratropium' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:55,163 - WARNING - No match for 'ipratropium' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:55,163 - INFO - searching for items with keyword 'papaverine' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:55,165 - WARNING - No match for 'papaverine' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:55,165 - INFO - searching for items with keyword 'repletion' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:55,167 - WARNING - No match for 'repletion' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:55,167 - INFO - searching for items with keyword 'remifentanil' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:55,169 - WARNING - No match for 'remifentanil' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:55,169 - INFO - searching for items with keyword 'isoproterenol' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:55,170 - WARNING - No match for 'isoproterenol' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:55,171 - INFO - searching for items with keyword 'sodium chloride' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:55,172 - WARNING - No match for 'sodium chloride' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:55,173 - INFO - searching for items with keyword 'plasma_lyte' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:55,174 - WARNING - No match for 'plasma_lyte' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:55,174 - INFO - searching for items with keyword 'liothyronine' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:55,176 - WARNING - No match for 'liothyronine' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:55,176 - INFO - searching for items with keyword 'bupivacaine' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:55,177 - WARNING - No match for 'bupivacaine' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:55,178 - INFO - searching for items with keyword 'pitocin' in column 'label' with case sensitive = False.
# 2025-09-11 16:02:55,179 - WARNING - No match for 'pitocin' in column 'label' with case sensitive = False.

# %% [markdown]
# # ETL

# %% [markdown]
# ## Load

# %%
med_admin_mapping = load_mapping_csv("med_admin")

logging.info("parsing the mapping files to identify relevant items and fetch corresponding events...")
med_item_ids = get_relevant_item_ids(
    mapping_df = med_admin_mapping, 
    decision_col = "decision", 
    excluded_labels = ["NO MAPPING", "UNSURE", "NOT AVAILABLE"]
    ) 

med_events = fetch_mimic_events(med_item_ids).pipe(convert_and_sort_datetime)
# Out:
# 2025-09-11 18:33:19,757 - INFO - parsing the mapping files to identify relevant items and fetch corresponding events...
# 2025-09-11 18:33:19,760 - INFO - querying the d_items table to identify which event tables to be separately queried for 123 items
# 2025-09-11 18:33:19,765 - INFO - identified 1 event tables to be separately queried: ['inputevents']
# 2025-09-11 18:33:19,766 - INFO - fetching events from inputevents table for 123 items
# 2025-09-11 18:33:19,766 - WARNING - inputevents not yet supported, thus returning all columns
# 2025-09-11 18:33:28,005 - INFO - fetched 7261761 events from inputevents table for 123 items
# 2025-09-11 18:33:28,008 - INFO - concatenated 7261761 events from 1 event table(s)

# %%
q = """
SELECT med_category, CAST(itemid AS INT) AS itemid, decision
    , COUNT(*) OVER (PARTITION BY itemid) AS count
FROM med_admin_mapping
WHERE decision in ('BOTH', 'CONTINUOUS', 'INTERMITTENT')
ORDER BY count DESC
"""
med_admin_mapping_c = duckdb.sql(q).df()
med_admin_mapping_c
# Out:
#                 med_category  itemid      decision  count
# 0                   dextrose  220949          BOTH      2
# 1      dextrose_in_water_d5w  220949          BOTH      2
# 2                     narcan  222021          BOTH      2
# 3                   naloxone  222021          BOTH      2
# 4                    albumin  220864    CONTINUOUS      1
# ..                       ...     ...           ...    ...
# 120              fluconazole  225869  INTERMITTENT      1
# 121  piperacillin_tazobactam  225893  INTERMITTENT      1
# 122               tobramycin  225902  INTERMITTENT      1
# 123               furosemide  228340    CONTINUOUS      1
# 124               amiodarone  229654    CONTINUOUS      1
#
# [125 rows x 4 columns]

# %% [markdown]
# ## Relevant columns

# %%
print(med_events.value_counts("ordercomponenttypedescription"))
print("\n--- which does not seem relevant")
# Out:
# ordercomponenttypedescription
# Main order parameter                                                                                    4850627
# Mixed solution                                                                                          2312078
# Additives                                         Ampoule                                                 99056
# Name: count, dtype: int64
#
# --- which does not seem relevant

# %%
med_events.value_counts('secondaryordercategoryname')
print("\n--- which does not seem relevant")
# Out:
# --- which does not seem relevant

# %%
find_intm_where_clause = """
ordercategoryname = '05-Med Bolus'
    OR ordercategorydescription = 'Drug Push'
    OR statusdescription = 'Bolus'
"""

# %%
query = f"""
SELECT subject_id, hadm_id
    , starttime, endtime --, storetime
    , linkorderid
    , statusdescription
    , med_category
    , rate, rateuom
    , amount, amountuom
    , patientweight
    , totalamount, totalamountuom, originalamount, originalrate
    , ordercategoryname, ordercategorydescription
    , e.itemid
    , e.label
    , m.decision AS item_class
    , CASE WHEN (endtime - starttime) = INTERVAL '1 minute'
        THEN 1 ELSE 0 END AS duration_1min
    -- flags to identify intermittents
    , CASE WHEN ordercategoryname = '05-Med Bolus'
        THEN 1 ELSE 0 END AS intm_by_ordercategoryname
    , CASE WHEN ordercategorydescription = 'Drug Push'
        THEN 1 ELSE 0 END AS intm_by_ordercategorydescription
    , CASE WHEN statusdescription = 'Bolus'
        THEN 1 ELSE 0 END AS intm_by_statusdescription
    , CASE WHEN item_class = 'INTERMITTENT'
        OR (item_class = 'BOTH' AND ({find_intm_where_clause}))
        THEN 'intm' ELSE 'cont' END AS "to_table"
FROM med_events e
LEFT JOIN med_admin_mapping_c m
    ON e.itemid = m.itemid
    AND m.decision IN ('BOTH', 'CONTINUOUS', 'INTERMITTENT')
ORDER BY hadm_id, starttime, linkorderid, med_category, endtime
"""
med_selected_and_mapped = duckdb.sql(query).df()

# %%
# RESUME as we have confirmed the working of left join 
# we can proceed

# %%
print("note that there is a 'Bolus' category under statusdescription, which is the MAR action")
med_selected_and_mapped.value_counts("statusdescription")
# Out:
# note that there is a 'Bolus' category under statusdescription, which is the MAR action
# statusdescription
# FinishedRunning    4679612
# ChangeDose/Rate    2942815
# Stopped             496306
# Paused              374954
# Bolus                 3645
# Reported                 1
# Name: count, dtype: int64

# %% [markdown]
# ## Split continuous and intermittents

# %%
query = f"""
SELECT *
FROM med_selected_and_mapped
WHERE item_class = 'CONTINUOUS'
    OR (item_class = 'BOTH' AND NOT ({find_intm_where_clause}))
ORDER BY hadm_id, med_category, starttime, endtime, linkorderid
"""
cont_only = duckdb.sql(query).df()

# %% [markdown]
# ## Process continous

# %% [markdown]
# ### Check missing dose `rate`

# %%
#RESUME
query = """
SELECT *
    , EXTRACT(EPOCH FROM (endtime - starttime)) / 60 AS duration_in_mins
    , amount / duration_in_mins AS rate_imputed
    , CONCAT(amountuom, '/min') AS rateuom_imputed
    , ABS(originalrate - rate_imputed) AS abs_diff
    , abs_diff / ((originalrate + rate_imputed) / 2) AS rel_diff
    , CASE WHEN rel_diff <= 0.01 OR abs_diff <= 0.000000001 THEN 1 ELSE 0 END AS close_rates
    , COALESCE(rate, rate_imputed) AS _rate
    , COALESCE(rateuom, rateuom_imputed) AS _rateuom
FROM cont_only
WHERE rate IS NULL
"""
cont_rate_missing = duckdb.sql(query).df()
print(f"Overall there are {cont_rate_missing.shape[0]} ({cont_rate_missing.shape[0]/cont_only.shape[0] * 100:.1f}%) rows with missing `rate`.")

mask = cont_rate_missing['close_rates'] == 0
print(f"Only {mask.mean() * 100:.1f}% ({mask.sum()}) of the imputed rates (using amount divided by duration) deviate from the `originalrate`.")
print("It seeems safe to use the imputed rates to fill the missing `rate`.")

mask2 = (cont_rate_missing['close_rates'] == 0) & (cont_rate_missing['originalrate'] == 0)
print(f"And {mask2.sum()/mask.sum() * 100:.1f}% ({mask2.sum()}) of the {mask.sum()} deviated cases are caused by a zero `originalrate`, which is odd and does not seem valid.")
cont_rate_missing.value_counts('med_category')
# Out:
# Overall there are 101059 (3.3%) rows with missing `rate`.
# Only 7.5% (7582) of the imputed rates (using amount divided by duration) deviate from the `originalrate`.
# It seeems safe to use the imputed rates to fill the missing `rate`.
# And 98.2% (7442) of the 7582 deviated cases are caused by a zero `originalrate`, which is odd and does not seem valid.
# med_category
# magnesium             82477
# sodium bicarbonate    10203
# dextrose               6047
# insulin                2245
# heparin                  87
# Name: count, dtype: int64

# %% [markdown]
# ### Flatten start-end timestamps to admin timestamps

# %%
# check monotonicity
q = """
SELECT *
    , LAG(endtime) OVER (PARTITION BY hadm_id, med_category, linkorderid ORDER BY starttime) AS endtime_prev
    , starttime < endtime_prev AS crossover
FROM cont_only
QUALIFY crossover is True
-- ORDER BY hadm_id, med_category, starttime, endtime, linkorderid
ORDER BY hadm_id, starttime, endtime, linkorderid, med_category
"""
crossovers = duckdb.sql(q).df()
print(f"given there are only {len(crossovers)} cases, we might consider dropping them all")
# Out:
# given there are only 20 cases, we might consider dropping them all

# %%
cont_lagged = med._prepare_for_timestamp_flattening(cont_only)

# %%
# Check pause #
# find demo data to test
query = """
SELECT *    
FROM cont_lagged
WHERE statusdescription = 'FinishedRunning'
    AND is_last_row = 0
    AND is_first_row = 0
    -- AND subject_id IN (SELECT DISTINCT CAST(patient_id AS INT) FROM pt_demo)
"""
df = duckdb.sql(query).df()

# %% [markdown]
# - 'Stopped' for the full sample (i.e. not just the MIMIC demo) would yield zero row, meaning it is not an issue.
# - 'Paused' and 'FinishedRunning' both yield results, meaning these are cases we need to hanlde. Unfortunately there are qualifying rows for 'FinishedRunning' in the demo data.

# %%
cont_flattened_staging = med._flatten_timestamps_staging(cont_only, "rate")
cont_flattened = med._flatten_timestamps(cont_flattened_staging, "rate")

# %%
q = """
SELECT *
    , CASE WHEN med_dose IS NULL THEN 1 ELSE 0 END AS dose_missing
FROM cont_flattened
WHERE mar_action_name = 'Paused' 
    AND subject_id IN (
        SELECT DISTINCT CAST(patient_id AS INT)
        FROM pt_demo
    )
"""
df2 = duckdb.sql(q).df()

# %%
longer = cont_only.query("linkorderid == 294375").melt(
    id_vars = [
        "hadm_id", "linkorderid", "med_category", 'rate', 'rateuom', 'statusdescription'
    ],
    value_vars = ["starttime", "endtime"],
    var_name = "time", value_name = "admin_dttm"
).sort_values(["hadm_id", "linkorderid", "med_category", "admin_dttm", "time"])

# %% [markdown]
# ## Intermittents (Archive)
# This part needs updating as it was built to generate cont only without considering keeping intm.

# %% [markdown]
# First identify the intermittents and observe their pattern.

# %%
query = f"""
SELECT *
    -- flags to identify intermittents
    , CASE WHEN ordercategoryname = '05-Med Bolus'
        THEN 1 ELSE 0 END AS intm_by_ordercategoryname
    , CASE WHEN ordercategorydescription = 'Drug Push'
        THEN 1 ELSE 0 END AS intm_by_ordercategorydescription
    , CASE WHEN statusdescription = 'Bolus'
        THEN 1 ELSE 0 END AS intm_by_statusdescription
    -- flags to count discrepencies, i.e. if all of the ostensible intermittents satisfy the 1min duration rule
    , CASE WHEN intm_by_ordercategorydescription = 1 AND duration_1min = 0
        THEN 1 ELSE 0 END AS not_1min_ordercategorydescription
    , CASE WHEN intm_by_ordercategoryname = 1 AND duration_1min = 0
        THEN 1 ELSE 0 END AS not_1min_ordercategoryname
    , CASE WHEN intm_by_statusdescription = 1 AND duration_1min = 0
        THEN 1 ELSE 0 END AS not_1min_statusdescription
FROM med_selected_and_mapped
WHERE {find_intm_where_clause}

"""
intm_only = duckdb.sql(query).df()

print(f"# of intermittents identified through ordercategoryname that failed the 1-min rule: {intm_only.not_1min_ordercategoryname.sum()}")
print(f"# of intermittents identified through ordercategorydescription that failed the 1-min rule: {intm_only.not_1min_ordercategorydescription.sum()}")
print(f"# of intermittents identified through statusdescription that failed the 1-min rule: {intm_only.not_1min_statusdescription.sum()}")
# Out:
# # of intermittents identified through ordercategoryname that failed the 1-min rule: 0
# # of intermittents identified through ordercategorydescription that failed the 1-min rule: 0
# # of intermittents identified through statusdescription that failed the 1-min rule: 1249

# %% [markdown]
# From the result it seems `intm_by_statusdescription` is particularly messy, while the other two can be used to safety identify intermittents.

# %%
query = """
SELECT *
FROM intm_only
WHERE not_1min_statusdescription = 1
"""
df = duckdb.sql(query).df()

# %%
# check if any of continuous events has 1-min duration # FIXME: possibly outdated
query = f"""
SELECT *
FROM med_selected_and_mapped
WHERE NOT ({find_intm_where_clause})
"""
intermittent_removed = duckdb.sql(query).df()

# %%
query = f"""
SELECT *
FROM intermittent_removed
WHERE duration_1min = 1
"""
cont_yet_1min = duckdb.sql(query).df()

# %% [markdown]
# ## Resolve duplicates
# This is possibly also outdated as we should now consider duplicate using the linearized time.

# %%
query = """
SELECT *
FROM cont_only
QUALIFY COUNT(*) OVER (PARTITION BY hadm_id, med_category, starttime, statusdescription) > 1
"""
mac_dups = duckdb.sql(query).df()

# %%
# final check there is no dup for god's sake
# mac_ldfd.duplicated(subset=meds_keycols, keep=False).sum()
