# %% [markdown]
# # Init

# %% [markdown]
# ## import

# %%
import pandas as pd
import numpy as np
import re

# %%
! cd ..
# Out:
# /Users/wliao0504/code/clif/CLIF-MIMIC
# /Users/wliao0504/code/clif/CLIF-MIMIC/.venv/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
pwd
# Out:
# '/Users/wliao0504/code/clif/CLIF-MIMIC'

# %%
# %load_ext autoreload
# %autoreload 2

from src.utils import check_duplicates, find_duplicates, read_from_rclif, clif_table_pathfinder, \
    mimic_table_pathfinder
# Out:
# loaded configuration from /Users/wliao0504/code/clif/CLIF-MIMIC/src/../config/config.json

# %% [markdown]
# ## load pipeline

# %%
import importlib
from src.tables import labs 
importlib.reload(labs)

from src import utils
importlib.reload(utils)
# Out:
# loaded configuration from /Users/wliao0504/code/clif/CLIF-MIMIC/src/../config/config.json
# <module 'src.utils' from '/Users/wliao0504/code/clif/CLIF-MIMIC/src/utils.py'>

# %%
from hamilton import driver
from hamilton.caching.stores.memory import InMemoryMetadataStore, InMemoryResultStore

dr = (
    driver.Builder()
    .with_modules(labs)
    # .with_cache(
    #     result_store=InMemoryResultStore(),
    #     metadata_store=InMemoryMetadataStore(),
    # )
    .build()
)
dr.display_all_functions()

# %% [markdown]
# # Dev

# %% [markdown]
# ## test

# %%
# results = dr.execute(["duplicates_removed", "schema_tested"])
results = labs._test()
error = results["schema_tested"]
# Out:
# 2025-04-27 12:34:24,964 - INFO - testing all...
# 2025-04-27 12:34:24,966 - INFO - initialized logging at logs/etl.log
# 2025-04-27 12:34:24,968 - INFO - starting data extraction
# 2025-04-27 12:34:24,969 - INFO - loading mapping...
# 2025-04-27 12:34:24,972 - INFO - filtering labs items...
# 2025-04-27 12:34:24,973 - INFO - identifying lab items to be extracted from labevents table...
# 2025-04-27 12:34:24,974 - INFO - extracting from labevents table...
# 2025-04-27 12:35:05,840 - INFO - constructing item id to name mapper...
# 2025-04-27 12:35:05,846 - INFO - constructing item id to category mapper...
# 2025-04-27 12:35:05,847 - INFO - translating labevents item ids to lab names and categories...
# 2025-04-27 12:35:07,138 - INFO - parsing lab comments to recover otherwise missing lab values...
# 2025-04-27 12:35:08,865 - INFO - renaming and reordering labevents columns...
# 2025-04-27 12:35:46,456 - INFO - converting units of measurement...
# 2025-04-27 12:35:49,683 - INFO - identifying lab items to be extracted from chartevents table...
# 2025-04-27 12:35:49,685 - INFO - extracting from chartevents table...
# 2025-04-27 12:35:49,686 - INFO - querying the d_items table to identify which event tables to be separately queried for 11 items
# 2025-04-27 12:35:49,692 - INFO - identified 1 event tables to be separately queried: ['chartevents']
# 2025-04-27 12:35:49,692 - INFO - fetching events from chartevents table for 11 items
# 2025-04-27 12:35:54,848 - INFO - fetched 1838520 events from chartevents table for 11 items
# 2025-04-27 12:35:54,849 - INFO - concatenated 1838520 events from 1 event table(s)
# 2025-04-27 12:35:54,850 - INFO - translating chartevents item ids to lab names and categories...
# 2025-04-27 12:35:54,903 - INFO - renaming and reordering chartevents columns...
# 2025-04-27 12:35:55,572 - INFO - merging lab events...
# 2025-04-27 12:36:06,279 - INFO - cleaning and recasting columns...
# 2025-04-27 12:36:31,195 - INFO - starting duplicates removal...
# 2025-04-27 12:36:54,314 - INFO - testing schema...

# %%
error.data.loc[error.failure_cases["index"],:]

# %%
le_labs_translated = results["le_labs_translated"]

# %%
dr.cache.view_run()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 dr.cache.view_run()
#
# File ~/.pyenv/versions/3.13.0/lib/python3.13/site-packages/hamilton/caching/adapter.py:483, in HamiltonCacheAdapter.view_run(self, run_id, output_file_path)
#     455 """View the dataflow execution, including cache hits/misses.
#     456
#     457 :param run_id: If ``None``, view the last run. If provided a ``run_id``, view that run.
#    (...)
#     480
#     481 """
#     482 if run_id is None:
# --> 483     run_id = self.last_run_id
#     485 fn_graph = self._fn_graphs[run_id]
#     486 logs = self.logs(run_id, level="debug")
#
# File ~/.pyenv/versions/3.13.0/lib/python3.13/site-packages/hamilton/caching/adapter.py:268, in HamiltonCacheAdapter.last_run_id(self)
#     265 @property
#     266 def last_run_id(self):
#     267     """Run id of the last started run. Not necessarily the last to complete."""
# --> 268     return self.run_ids[-1]
#
# IndexError: list index out of range

# %% [markdown]
# ## check NA time issue

# %%
results = dr.execute(["ce_labs_renamed_reordered", "le_labs_renamed_reordered", "columns_recast"])
# Out:
# 2025-04-27 12:16:48,476 - INFO - starting data extraction
# 2025-04-27 12:16:48,477 - INFO - loading mapping...
# 2025-04-27 12:16:48,481 - INFO - filtering labs items...
# 2025-04-27 12:16:48,482 - INFO - identifying lab items to be extracted from chartevents table...
# 2025-04-27 12:16:48,483 - INFO - extracting from chartevents table...
# 2025-04-27 12:16:48,483 - INFO - querying the d_items table to identify which event tables to be separately queried for 11 items
# 2025-04-27 12:16:48,486 - INFO - identified 1 event tables to be separately queried: ['chartevents']
# 2025-04-27 12:16:48,487 - INFO - fetching events from chartevents table for 11 items
# 2025-04-27 12:16:53,181 - INFO - fetched 1838520 events from chartevents table for 11 items
# 2025-04-27 12:16:53,182 - INFO - concatenated 1838520 events from 1 event table(s)
# 2025-04-27 12:16:53,182 - INFO - constructing item id to name mapper...
# 2025-04-27 12:16:53,184 - INFO - constructing item id to category mapper...
# 2025-04-27 12:16:53,184 - INFO - translating chartevents item ids to lab names and categories...
# 2025-04-27 12:16:53,234 - INFO - renaming and reordering chartevents columns...
# 2025-04-27 12:16:53,628 - INFO - identifying lab items to be extracted from labevents table...
# 2025-04-27 12:16:53,629 - INFO - extracting from labevents table...
# 2025-04-27 12:17:22,885 - INFO - translating labevents item ids to lab names and categories...
# 2025-04-27 12:17:23,874 - INFO - parsing lab comments to recover otherwise missing lab values...
# 2025-04-27 12:17:24,836 - INFO - renaming and reordering labevents columns...
# 2025-04-27 12:17:42,143 - INFO - converting units of measurement...
# 2025-04-27 12:17:44,615 - INFO - merging lab events...
# 2025-04-27 12:17:52,189 - INFO - cleaning and recasting columns...

# %%
ce_labs_renamed_reordered: pd.DataFrame = results['ce_labs_renamed_reordered']
le_labs_renamed_reordered: pd.DataFrame = results['le_labs_renamed_reordered']
columns_recast: pd.DataFrame = results['columns_recast']

# %%
# check that the chartevents table are pretty "clean" -- with no NA values for any of the 3 columns
mask = ce_labs_renamed_reordered["lab_value_numeric"].isna()
print(f"{mask.sum()} ({mask.mean()*100:.1f}%) rows have NaN for `lab_value_numeric` in 'ce_labs_renamed_reordered'")

mask = ce_labs_renamed_reordered["lab_collect_dttm"].isna()
print(f"{mask.sum()} ({mask.mean()*100:.1f}%) rows have NaN for `lab_collect_dttm` in 'ce_labs_renamed_reordered'")

mask = ce_labs_renamed_reordered["lab_result_dttm"].isna()
print(f"{mask.sum()} ({mask.mean()*100:.1f}%) rows have NaN for `lab_result_dttm` in 'ce_labs_renamed_reordered'")
na_result_dttm = ce_labs_renamed_reordered[mask]
na_result_dttm.head()
# Out:
# 0 (0.0%) rows have NaN for `lab_value_numeric` in 'ce_labs_renamed_reordered'
# 0 (0.0%) rows have NaN for `lab_collect_dttm` in 'ce_labs_renamed_reordered'
# 0 (0.0%) rows have NaN for `lab_result_dttm` in 'ce_labs_renamed_reordered'
# Empty DataFrame
# Columns: [hospitalization_id, lab_order_dttm, lab_collect_dttm, lab_result_dttm, lab_order_name, lab_order_category, lab_name, lab_category, lab_value, lab_value_numeric, reference_unit, lab_specimen_name, lab_specimen_category, lab_loinc_code, itemid]
# Index: []

# %%
# check that the issues are with labevents table
mask = le_labs_renamed_reordered["lab_value_numeric"].isna()
print(f"{mask.sum()} ({mask.mean()*100:.1f}%) rows have NaN for `lab_value_numeric` in 'le_labs_renamed_reordered'")
na_lab_value_numeric = le_labs_renamed_reordered[mask]

mask = le_labs_renamed_reordered["lab_collect_dttm"].isna()
print(f"{mask.sum()} ({mask.mean()*100:.1f}%) rows have NaN for `lab_collect_dttm` in 'le_labs_renamed_reordered'")

mask = le_labs_renamed_reordered["lab_result_dttm"].isna()
print(f"{mask.sum()} ({mask.mean()*100:.1f}%) rows have NaN for `lab_result_dttm` in 'le_labs_renamed_reordered'")
na_result_dttm = le_labs_renamed_reordered[mask]
na_result_dttm.head()
# Out:
# 80213 (0.2%) rows have NaN for `lab_value_numeric` in 'le_labs_renamed_reordered'
# 0 (0.0%) rows have NaN for `lab_collect_dttm` in 'le_labs_renamed_reordered'
# 35 (0.0%) rows have NaN for `lab_result_dttm` in 'le_labs_renamed_reordered'
#          hospitalization_id  lab_order_dttm    lab_collect_dttm  \
# 467869             25061074             NaN 2173-03-24 18:02:00
# 467870             25061074             NaN 2173-03-24 18:02:00
# 467871             25061074             NaN 2173-03-24 18:02:00
# 2805117            28168342             NaN 2164-08-10 09:41:00
# 4775322            29789360             NaN 2163-12-30 05:23:00
#
#         lab_result_dttm  lab_order_name  lab_order_category lab_name  \
# 467869              NaT             NaN                 NaN     pCO2
# 467870              NaT             NaN                 NaN       pH
# 467871              NaT             NaN                 NaN      pO2
# 2805117             NaT             NaN                 NaN       pH
# 4775322             NaT             NaN                 NaN     pCO2
#
#           lab_category lab_value  lab_value_numeric reference_unit  \
# 467869   pco2_arterial      None                NaN          mm Hg
# 467870     ph_arterial      None                NaN          units
# 467871    po2_arterial      None                NaN          mm Hg
# 2805117    ph_arterial      None                NaN          units
# 4775322  pco2_arterial      None                NaN          mm Hg
#
#          lab_specimen_name  lab_specimen_category  lab_loinc_code  itemid
# 467869                 NaN                    NaN             NaN   50818
# 467870                 NaN                    NaN             NaN   50820
# 467871                 NaN                    NaN             NaN   50821
# 2805117                NaN                    NaN             NaN   50820
# 4775322                NaN                    NaN             NaN   50818

# %% [markdown]
# This prompted us to not remove these rows and instead keep them as they are in tandom with the `lab_value` which is sourced from the original comment, in case we had any issue with parsing the comments.

# %%
na_lab_value_numeric
# Out:
#           hospitalization_id  lab_order_dttm    lab_collect_dttm  \
# 2808                22987108             NaN 2146-07-12 03:10:00
# 6696                27660382             NaN 2146-03-11 05:00:00
# 6697                27660382             NaN 2146-03-11 05:00:00
# 6698                27660382             NaN 2146-03-11 05:00:00
# 7323                24757479             NaN 2146-06-29 00:00:00
# ...                      ...             ...                 ...
# 44330415            26445739             NaN 2113-12-14 06:46:00
# 44330416            26445739             NaN 2113-12-14 06:46:00
# 44332303            22183763             NaN 2114-02-17 21:40:00
# 44332358            22183763             NaN 2114-02-18 14:17:00
# 44334214            20022720             NaN 2157-04-04 13:00:00
#
#              lab_result_dttm  lab_order_name  lab_order_category  \
# 2808     2146-07-12 04:55:00             NaN                 NaN
# 6696     2146-03-11 06:58:00             NaN                 NaN
# 6697     2146-03-11 06:58:00             NaN                 NaN
# 6698     2146-03-11 06:58:00             NaN                 NaN
# 7323     2146-06-29 01:21:00             NaN                 NaN
# ...                      ...             ...                 ...
# 44330415 2113-12-14 07:40:00             NaN                 NaN
# 44330416 2113-12-14 07:40:00             NaN                 NaN
# 44332303 2114-02-17 22:34:00             NaN                 NaN
# 44332358 2114-02-18 16:14:00             NaN                 NaN
# 44334214 2157-04-04 15:04:00             NaN                 NaN
#
#                 lab_name       lab_category          lab_value  \
# 2808          Hemoglobin         hemoglobin  UNABLE TO REPORT.
# 6696             INR(PT)                inr  UNABLE TO REPORT.
# 6697                  PT                 pt                ___
# 6698                 PTT                ptt  UNABLE TO REPORT.
# 7323           Basophils  basophils_percent          NOT DONE.
# ...                  ...                ...                ...
# 44330415              PT                 pt                ___
# 44330416             PTT                ptt  UNABLE TO REPORT.
# 44332303  Platelet Count     platelet_count                ___
# 44332358  Platelet Count     platelet_count  UNABLE TO REPORT.
# 44334214       Potassium          potassium                ___
#
#           lab_value_numeric reference_unit  lab_specimen_name  \
# 2808                    NaN           g/dL                NaN
# 6696                    NaN           None                NaN
# 6697                    NaN            sec                NaN
# 6698                    NaN            sec                NaN
# 7323                    NaN              %                NaN
# ...                     ...            ...                ...
# 44330415                NaN            sec                NaN
# 44330416                NaN            sec                NaN
# 44332303                NaN           K/uL                NaN
# 44332358                NaN           K/uL                NaN
# 44334214                NaN          mEq/L                NaN
#
#           lab_specimen_category  lab_loinc_code  itemid
# 2808                        NaN             NaN   51222
# 6696                        NaN             NaN   51237
# 6697                        NaN             NaN   51274
# 6698                        NaN             NaN   51275
# 7323                        NaN             NaN   51146
# ...                         ...             ...     ...
# 44330415                    NaN             NaN   51274
# 44330416                    NaN             NaN   51275
# 44332303                    NaN             NaN   51265
# 44332358                    NaN             NaN   51265
# 44334214                    NaN             NaN   50971
#
# [80213 rows x 15 columns]

# %%
mask = le_labs_renamed_reordered["lab_collect_dttm"].isna()
print(f"{mask.sum()} ({mask.mean()*100:.1f}%) rows have NaN for `lab_collect_dttm`")

mask = le_labs_renamed_reordered["lab_result_dttm"].isna()
print(f"{mask.sum()} ({mask.mean()*100:.1f}%) rows have NaN for `lab_result_dttm`")
na_result_dttm = le_labs_renamed_reordered[mask]
na_result_dttm.head()
# Out:
# 0 (0.0%) rows have NaN for `lab_collect_dttm`
# 35 (0.0%) rows have NaN for `lab_result_dttm`
#          hospitalization_id  lab_order_dttm    lab_collect_dttm  \
# 467869             25061074             NaN 2173-03-24 18:02:00
# 467870             25061074             NaN 2173-03-24 18:02:00
# 467871             25061074             NaN 2173-03-24 18:02:00
# 2805117            28168342             NaN 2164-08-10 09:41:00
# 4775322            29789360             NaN 2163-12-30 05:23:00
#
#         lab_result_dttm  lab_order_name  lab_order_category lab_name  \
# 467869              NaT             NaN                 NaN     pCO2
# 467870              NaT             NaN                 NaN       pH
# 467871              NaT             NaN                 NaN      pO2
# 2805117             NaT             NaN                 NaN       pH
# 4775322             NaT             NaN                 NaN     pCO2
#
#           lab_category lab_value  lab_value_numeric reference_unit  \
# 467869   pco2_arterial      None                NaN          mm Hg
# 467870     ph_arterial      None                NaN          units
# 467871    po2_arterial      None                NaN          mm Hg
# 2805117    ph_arterial      None                NaN          units
# 4775322  pco2_arterial      None                NaN          mm Hg
#
#          lab_specimen_name  lab_specimen_category  lab_loinc_code  itemid
# 467869                 NaN                    NaN             NaN   50818
# 467870                 NaN                    NaN             NaN   50820
# 467871                 NaN                    NaN             NaN   50821
# 2805117                NaN                    NaN             NaN   50820
# 4775322                NaN                    NaN             NaN   50818

# %%
mask = columns_recast["lab_collect_dttm"].isna()
print(f"{mask.sum()} ({mask.mean()*100:.1f}%) rows have NaN for `lab_collect_dttm`")

mask = columns_recast["lab_result_dttm"].isna()
print(f"{mask.sum()} ({mask.mean()*100:.1f}%) rows have NaN for `lab_result_dttm`")
na_result_dttm = columns_recast[mask]
na_result_dttm.head()
# Out:
# 0 (0.0%) rows have NaN for `lab_collect_dttm`
# 35 (0.0%) rows have NaN for `lab_result_dttm`
#         hospitalization_id lab_order_dttm          lab_collect_dttm  \
# 471517            25061074            NaT 2173-03-24 23:02:00+00:00
# 471518            25061074            NaT 2173-03-24 23:02:00+00:00
# 471519            25061074            NaT 2173-03-24 23:02:00+00:00
# 2851518           28168342            NaT 2164-08-10 14:41:00+00:00
# 4810753           29789360            NaT 2163-12-30 10:23:00+00:00
#
#         lab_result_dttm lab_order_name lab_order_category lab_name  \
# 471517              NaT           <NA>               <NA>     pCO2
# 471518              NaT           <NA>               <NA>       pH
# 471519              NaT           <NA>               <NA>      pO2
# 2851518             NaT           <NA>               <NA>       pH
# 4810753             NaT           <NA>               <NA>     pCO2
#
#           lab_category lab_value  lab_value_numeric reference_unit  \
# 471517   pco2_arterial      None                NaN          mm Hg
# 471518     ph_arterial      None                NaN          units
# 471519    po2_arterial      None                NaN          mm Hg
# 2851518    ph_arterial      None                NaN          units
# 4810753  pco2_arterial      None                NaN          mm Hg
#
#         lab_specimen_name lab_specimen_category lab_loinc_code
# 471517               <NA>                  <NA>           <NA>
# 471518               <NA>                  <NA>           <NA>
# 471519               <NA>                  <NA>           <NA>
# 2851518              <NA>                  <NA>           <NA>
# 4810753              <NA>                  <NA>           <NA>

# %% [markdown]
# A lot of these NA lab result time is valid in the sense that there was no value recorded either, indicating there was likely something that might have gone wrong in the labs so not result is available. This should prompt us to look closer into the comment issue

# %% [markdown]
# ## dedup

# %%
labs_events_f = read_from_rclif("labs_intm")

# %%
len(labs_events_f)
# Out:
# 46174325

# %%
labs_dups = find_duplicates(labs_events_f, ["hospitalization_id", "lab_collect_dttm", "lab_result_dttm", "lab_category"]) \
    .sort_values(["hospitalization_id", "lab_collect_dttm", "lab_result_dttm", "lab_category"])

labs_dups
# Out:
#          hospitalization_id lab_order_dttm    lab_collect_dttm  \
# 9683715            20000147            NaT 2121-08-30 17:38:00
# 44761220           20000147            NaT 2121-08-30 17:38:00
# 9683716            20000147            NaT 2121-08-30 17:38:00
# 44762337           20000147            NaT 2121-08-30 17:38:00
# 9683717            20000147            NaT 2121-08-30 17:38:00
# ...                     ...            ...                 ...
# 44775215           29999625            NaT 2157-11-24 02:37:00
# 4567471            29999625            NaT 2157-11-24 02:37:00
# 44776501           29999625            NaT 2157-11-24 02:37:00
# 4567472            29999625            NaT 2157-11-24 02:37:00
# 44775627           29999625            NaT 2157-11-24 02:37:00
#
#              lab_result_dttm lab_order_name lab_order_category  \
# 9683715  2121-08-30 17:39:00
# 44761220 2121-08-30 17:39:00
# 9683716  2121-08-30 17:39:00
# 44762337 2121-08-30 17:39:00
# 9683717  2121-08-30 17:39:00
# ...                      ...            ...                ...
# 44775215 2157-11-24 02:40:00
# 4567471  2157-11-24 02:40:00
# 44776501 2157-11-24 02:40:00
# 4567472  2157-11-24 02:40:00
# 44775627 2157-11-24 02:40:00
#
#                        lab_name   lab_category lab_value  lab_value_numeric  \
# 9683715                    pCO2  pco2_arterial        35              35.00
# 44761220  Arterial CO2 Pressure  pco2_arterial        35              35.00
# 9683716                      pH    ph_arterial      7.41               7.41
# 44762337          PH (Arterial)    ph_arterial      7.41               7.41
# 9683717                     pO2   po2_arterial       390             390.00
# ...                         ...            ...       ...                ...
# 44775215  Arterial CO2 Pressure  pco2_arterial        43              43.00
# 4567471                      pH    ph_arterial      7.41               7.41
# 44776501          PH (Arterial)    ph_arterial      7.41               7.41
# 4567472                     pO2   po2_arterial        81              81.00
# 44775627   Arterial O2 pressure   po2_arterial        81              81.00
#
#          reference_unit lab_specimen_name lab_specimen_category lab_loinc_code
# 9683715           mm Hg
# 44761220           mmHg
# 9683716           units
# 44762337          units
# 9683717           mm Hg
# ...                 ...               ...                   ...            ...
# 44775215           mmHg
# 4567471           units
# 44776501          units
# 4567472           mm Hg
# 44775627           mmHg
#
# [2590858 rows x 14 columns]

# %%
# Drop trivial duplicates
labs_events_fd = labs_events_f.drop_duplicates(
        subset = ["hospitalization_id", "lab_collect_dttm", "lab_result_dttm", "lab_category", "lab_value_numeric"],
        inplace = False)

# %% [markdown]
# After we drop the trivial duplicates (where the values are the same and thus simply repeated), we are left with 4015 non-trivial cases:

# %%
labs_dups_d = find_duplicates(labs_events_fd, ["hospitalization_id", "lab_collect_dttm", "lab_result_dttm", "lab_category"]) \
    .sort_values(["hospitalization_id", "lab_collect_dttm", "lab_result_dttm", "lab_category"])

labs_dups_d
# Out:
#          hospitalization_id lab_order_dttm    lab_collect_dttm  \
# 18566630           20012928            NaT 2123-03-02 04:45:00
# 18566642           20012928            NaT 2123-03-02 04:45:00
# 18566631           20012928            NaT 2123-03-02 04:45:00
# 18566643           20012928            NaT 2123-03-02 04:45:00
# 38581298           20025172            NaT 2139-12-01 08:38:00
# ...                     ...            ...                 ...
# 22382782           29983564            NaT 2128-06-07 06:47:00
# 22382766           29983564            NaT 2128-06-07 06:47:00
# 22382783           29983564            NaT 2128-06-07 06:47:00
# 44677336           29984509            NaT 2158-10-22 12:00:00
# 44688274           29984509            NaT 2158-10-22 12:00:00
#
#              lab_result_dttm lab_order_name lab_order_category  \
# 18566630 2123-03-02 05:48:00
# 18566642 2123-03-02 05:48:00
# 18566631 2123-03-02 05:48:00
# 18566643 2123-03-02 05:48:00
# 38581298 2139-12-01 10:31:00
# ...                      ...            ...                ...
# 22382782 2128-06-07 08:42:00
# 22382766 2128-06-07 08:42:00
# 22382783 2128-06-07 08:42:00
# 44677336 2158-10-22 12:04:00
# 44688274 2158-10-22 12:04:00
#
#                       lab_name      lab_category lab_value  lab_value_numeric  \
# 18566630            Hemoglobin        hemoglobin       7.7                7.7
# 18566642            Hemoglobin        hemoglobin       7.6                7.6
# 18566631        Platelet Count    platelet_count       148              148.0
# 18566643        Platelet Count    platelet_count       139              139.0
# 38581298            Hemoglobin        hemoglobin       7.7                7.7
# ...                        ...               ...       ...                ...
# 22382782                    PT                pt      12.3               12.3
# 22382766                   PTT               ptt      28.4               28.4
# 22382783                   PTT               ptt      28.7               28.7
# 44677336  Mixed Venous O2% Sat  so2_mixed_venous        42               42.0
# 44688274                  SvO2  so2_mixed_venous        46               46.0
#
#          reference_unit lab_specimen_name lab_specimen_category lab_loinc_code
# 18566630           g/dL
# 18566642           g/dL
# 18566631           K/uL
# 18566643           K/uL
# 38581298           g/dL
# ...                 ...               ...                   ...            ...
# 22382782            sec
# 22382766            sec
# 22382783            sec
# 44677336              %
# 44688274              %
#
# [4015 rows x 14 columns]

# %% [markdown]
# If we discard duplicates that result from many to one mapping (which we can solve by assigning duduplication rank), we are left with the case of geneinue duplicates from the same item (displayed below). Luckily, most of them seem to be close-value duplicates (which we may define as being within 10% from each other). Then the remaining are the most thorny cases: observations of the same item of the same patient at same time that differ dramatically in values. Should we drop either? both? Or are they legit duplicates from two different samples / specimens?

# %%
labs_dups_d2 = find_duplicates(labs_events_fd, ["hospitalization_id", "lab_collect_dttm", "lab_result_dttm", "lab_name"]) \
    .sort_values(["hospitalization_id", "lab_collect_dttm", "lab_result_dttm", "lab_category"])

# %%
# remove some empty columns for better display
labs_dups_d2.drop(
    columns = ["lab_order_dttm", "lab_order_name", "lab_order_category", "lab_specimen_name", "lab_specimen_category", "lab_loinc_code"],
    inplace = True
    )
labs_dups_d2
# Out:
#          hospitalization_id    lab_collect_dttm     lab_result_dttm  \
# 18566630           20012928 2123-03-02 04:45:00 2123-03-02 05:48:00
# 18566642           20012928 2123-03-02 04:45:00 2123-03-02 05:48:00
# 18566631           20012928 2123-03-02 04:45:00 2123-03-02 05:48:00
# 18566643           20012928 2123-03-02 04:45:00 2123-03-02 05:48:00
# 38581298           20025172 2139-12-01 08:38:00 2139-12-01 10:31:00
# ...                     ...                 ...                 ...
# 39224708           29977045 2134-12-23 11:35:00 2134-12-23 13:16:00
# 22382765           29983564 2128-06-07 06:47:00 2128-06-07 08:42:00
# 22382782           29983564 2128-06-07 06:47:00 2128-06-07 08:42:00
# 22382766           29983564 2128-06-07 06:47:00 2128-06-07 08:42:00
# 22382783           29983564 2128-06-07 06:47:00 2128-06-07 08:42:00
#
#                 lab_name    lab_category lab_value  lab_value_numeric  \
# 18566630      Hemoglobin      hemoglobin       7.7                7.7
# 18566642      Hemoglobin      hemoglobin       7.6                7.6
# 18566631  Platelet Count  platelet_count       148              148.0
# 18566643  Platelet Count  platelet_count       139              139.0
# 38581298      Hemoglobin      hemoglobin       7.7                7.7
# ...                  ...             ...       ...                ...
# 39224708      Hemoglobin      hemoglobin       6.9                6.9
# 22382765              PT              pt      12.4               12.4
# 22382782              PT              pt      12.3               12.3
# 22382766             PTT             ptt      28.4               28.4
# 22382783             PTT             ptt      28.7               28.7
#
#          reference_unit
# 18566630           g/dL
# 18566642           g/dL
# 18566631           K/uL
# 18566643           K/uL
# 38581298           g/dL
# ...                 ...
# 39224708           g/dL
# 22382765            sec
# 22382782            sec
# 22382766            sec
# 22382783            sec
#
# [3615 rows x 8 columns]

# %%
labs_dups_d2
# Out:
#          hospitalization_id    lab_collect_dttm     lab_result_dttm  \
# 18566630           20012928 2123-03-02 04:45:00 2123-03-02 05:48:00
# 18566642           20012928 2123-03-02 04:45:00 2123-03-02 05:48:00
# 18566631           20012928 2123-03-02 04:45:00 2123-03-02 05:48:00
# 18566643           20012928 2123-03-02 04:45:00 2123-03-02 05:48:00
# 38581298           20025172 2139-12-01 08:38:00 2139-12-01 10:31:00
# ...                     ...                 ...                 ...
# 39224708           29977045 2134-12-23 11:35:00 2134-12-23 13:16:00
# 22382765           29983564 2128-06-07 06:47:00 2128-06-07 08:42:00
# 22382782           29983564 2128-06-07 06:47:00 2128-06-07 08:42:00
# 22382766           29983564 2128-06-07 06:47:00 2128-06-07 08:42:00
# 22382783           29983564 2128-06-07 06:47:00 2128-06-07 08:42:00
#
#                 lab_name    lab_category lab_value  lab_value_numeric  \
# 18566630      Hemoglobin      hemoglobin       7.7                7.7
# 18566642      Hemoglobin      hemoglobin       7.6                7.6
# 18566631  Platelet Count  platelet_count       148              148.0
# 18566643  Platelet Count  platelet_count       139              139.0
# 38581298      Hemoglobin      hemoglobin       7.7                7.7
# ...                  ...             ...       ...                ...
# 39224708      Hemoglobin      hemoglobin       6.9                6.9
# 22382765              PT              pt      12.4               12.4
# 22382782              PT              pt      12.3               12.3
# 22382766             PTT             ptt      28.4               28.4
# 22382783             PTT             ptt      28.7               28.7
#
#          reference_unit
# 18566630           g/dL
# 18566642           g/dL
# 18566631           K/uL
# 18566643           K/uL
# 38581298           g/dL
# ...                 ...
# 39224708           g/dL
# 22382765            sec
# 22382782            sec
# 22382766            sec
# 22382783            sec
#
# [3615 rows x 8 columns]

# %%
len(labs_events_f)
# Out:
# 46174325

# %%
f"{(3615 / len(labs_events_f)) * 100:.2f}%"
# Out:
# 7.829026195835023e-05

# %% [markdown]
# ## handle NA lab values (`valuenum`)
# sometimes the `value` or `valuenum` are NA, or in a weird blank form "__". need to check if they are always accompanied by otherwise useful comments. This seems a problem unique to the labs events (le) table.

# %%
df_le: pd.DataFrame = le_labs_translated

df_le.head()
# Out:
#    labevent_id  subject_id   hadm_id  specimen_id  itemid order_provider_id  \
# 0       373283    10023274  25335412     18902407   51146              <NA>
# 1       373284    10023274  25335412     18902407   51200              <NA>
# 2       373286    10023274  25335412     18902407   51222              <NA>
# 3       373287    10023274  25335412     18902407   51244              <NA>
# 4       373291    10023274  25335412     18902407   51254              <NA>
#
#             charttime           storetime value  valuenum valueuom  \
# 0 2155-01-08 21:21:00 2155-01-08 21:52:00   0.4       0.4        %
# 1 2155-01-08 21:21:00 2155-01-08 21:52:00   0.2       0.2        %
# 2 2155-01-08 21:21:00 2155-01-08 21:52:00  13.6      13.6     g/dL
# 3 2155-01-08 21:21:00 2155-01-08 21:52:00  21.1      21.1        %
# 4 2155-01-08 21:21:00 2155-01-08 21:52:00   7.8       7.8        %
#
#    ref_range_lower  ref_range_upper      flag priority comments     lab_name  \
# 0              0.0              1.0      <NA>     STAT     <NA>    Basophils
# 1              1.0              7.0  abnormal     STAT     <NA>  Eosinophils
# 2             13.7             17.5  abnormal     STAT     <NA>   Hemoglobin
# 3             19.0             53.0      <NA>     STAT     <NA>  Lymphocytes
# 4              5.0             13.0      <NA>     STAT     <NA>    Monocytes
#
#           lab_category
# 0    basophils_percent
# 1  eosinophils_percent
# 2           hemoglobin
# 3  lymphocytes_percent
# 4    monocytes_percent

# %%
# We start by examining the numeric value field `valuenum`
mask = df_le['valuenum'].isna()
print(f"{mask.sum()} ({mask.mean()*100:.1f}%) rows have NaN for `valuenum`")
na_valuenum: pd.DataFrame = df_le[mask]
na_valuenum.head()
# Out:
# 223966 (0.5%) rows have NaN for `valuenum`
#      labevent_id  subject_id   hadm_id  specimen_id  itemid order_provider_id  \
# 11        373308    10023274  25335412     61097845   51003              <NA>
# 35        373346    10023274  25335412     93866128   51003              <NA>
# 114       373669    10023340  29144403     83673643   51003              <NA>
# 126       373683    10023340  29144403     96681834   51003              <NA>
# 142       373711    10023340  29144403      6558347   51003              <NA>
#
#               charttime           storetime value  valuenum valueuom  \
# 11  2155-01-08 21:21:00 2155-01-08 22:17:00  <NA>      <NA>    ng/mL
# 35  2155-01-09 06:55:00 2155-01-09 09:06:00  <NA>      <NA>    ng/mL
# 114 2122-12-12 06:45:00 2122-12-12 09:10:00  <NA>      <NA>    ng/mL
# 126 2122-12-12 18:30:00 2122-12-12 19:33:00  <NA>      <NA>    ng/mL
# 142 2122-12-13 08:20:00 2122-12-13 10:36:00  <NA>      <NA>    ng/mL
#
#      ref_range_lower  ref_range_upper  flag priority  \
# 11               0.0             0.01  <NA>     STAT
# 35               0.0             0.01  <NA>  ROUTINE
# 114              0.0             0.01  <NA>  ROUTINE
# 126              0.0             0.01  <NA>     STAT
# 142              0.0             0.01  <NA>     STAT
#
#                                             comments    lab_name lab_category
# 11   <0.01.  cTropnT > 0.10 ng/mL suggests Acute MI.  Troponin T   troponin_t
# 35   <0.01.  cTropnT > 0.10 ng/mL suggests Acute MI.  Troponin T   troponin_t
# 114  <0.01.  CTROPNT > 0.10 NG/ML SUGGESTS ACUTE MI.  Troponin T   troponin_t
# 126  <0.01.  CTROPNT > 0.10 NG/ML SUGGESTS ACUTE MI.  Troponin T   troponin_t
# 142  <0.01.  CTROPNT > 0.10 NG/ML SUGGESTS ACUTE MI.  Troponin T   troponin_t

# %%
# and look at the prevalence of NA by lab_name
na_valuenum.value_counts('lab_name')
# Out:
# lab_name
# Troponin T                         107398
# Bilirubin, Total                    14913
# PTT                                 13217
# Platelet Count                      10364
# INR(PT)                             10103
# PT                                   9873
# Alanine Aminotransferase (ALT)       9445
# Hemoglobin                           5463
# Basophils                            4286
# Neutrophils                          4286
# Eosinophils                          4283
# Monocytes                            4279
# Lymphocytes                          4279
# Absolute Basophil Count              4002
# Bilirubin, Direct                    3417
# C-Reactive Protein                   2843
# Urea Nitrogen                        1809
# Potassium                            1428
# Creatinine                           1217
# Glucose                               765
# pCO2                                  635
# Bicarbonate                           617
# Asparate Aminotransferase (AST)       568
# Ferritin                              471
# Chloride                              407
# Magnesium                             395
# Sodium                                359
# Calcium, Total                        357
# pH                                    337
# pO2                                   324
# Free Calcium                          271
# Phosphate                             265
# Lactate                               207
# Potassium, Whole Blood                192
# Oxygen Saturation                     175
# Sedimentation Rate                    175
# Alkaline Phosphatase                  119
# Albumin                               117
# Lactate Dehydrogenase (LD)            107
# Chloride, Whole Blood                  67
# Sodium, Whole Blood                    50
# Creatinine, Whole Blood                33
# Bilirubin, Indirect                    29
# High-Sensitivity CRP                    8
# Protein, Total                          7
# Lymphocytes, Percent                    2
# WBC Count                               2
# Name: count, dtype: int64

# %%
# also check the join distribution considering comment patterns
dist = na_valuenum.value_counts(['lab_name', 'comments'])\
    .to_frame() \
    .reset_index()
dist
# Out:
#                            lab_name  \
# 0                        Troponin T
# 1                        Troponin T
# 2                  Bilirubin, Total
# 3    Alanine Aminotransferase (ALT)
# 4                               PTT
# ..                              ...
# 411             Sodium, Whole Blood
# 412                              PT
# 413                      Troponin T
# 414                              PT
# 415      Lactate Dehydrogenase (LD)
#
#                                               comments  count
# 0      <0.01.  CTROPNT > 0.10 NG/ML SUGGESTS ACUTE MI.  66054
# 1      <0.01.  cTropnT > 0.10 ng/mL suggests Acute MI.  40239
# 2                                                <0.2.  14789
# 3                                                  <5.   8817
# 4                                    UNABLE TO REPORT.   6814
# ..                                                 ...    ...
# 411                                         GREEN TOP.      1
# 412                 CITRATE NOT ADJUSTED FOR HIGH HCT.      1
# 413         .  cTropnT > 0.10 ng/mL suggests Acute MI.      1
# 414                        150 IS HIGHEST MEASURED PT.      1
# 415  SLIGHT HEMOLYSIS.  HEMOLYSIS FALSELY ELEVATES ...      1
#
# [416 rows x 3 columns]

# %%
na_valuenum.value_counts(['comments'])\
    .to_frame() \
    .reset_index()
# Out:
#                                               comments  count
# 0      <0.01.  CTROPNT > 0.10 NG/ML SUGGESTS ACUTE MI.  66054
# 1      <0.01.  cTropnT > 0.10 ng/mL suggests Acute MI.  40239
# 2                                                  ___  32883
# 3                                    UNABLE TO REPORT.  24343
# 4                                                <0.2.  18008
# ..                                                 ...    ...
# 232  HEMOLYSIS FALSELY ELEVATES Mg.  HEMOLYZED, MOD...      1
# 233                                  CHECKED FOR CLOT.      1
# 234                                 ICTERIC, SLIGHTLY.      1
# 235                                  LIPEMIC SPECIMEN.      1
# 236  SLIGHT HEMOLYSIS.  HEMOLYSIS FALSELY ELEVATES ...      1
#
# [237 rows x 2 columns]

# %%
# compare the missing rate by lab_name
df_le['valuenum'].isna().groupby(df_le['lab_name']).mean()
# Out:
# lab_name
# Absolute Basophil Count            0.014871
# Alanine Aminotransferase (ALT)     0.011932
# Albumin                            0.000284
# Alkaline Phosphatase               0.000155
# Asparate Aminotransferase (AST)    0.000719
# Basophils                          0.009275
# Bicarbonate                        0.000242
# Bilirubin, Direct                  0.086086
# Bilirubin, Indirect                0.000841
# Bilirubin, Total                   0.019190
# C-Reactive Protein                 0.046338
# Calcium, Total                     0.000161
# Chloride                           0.000156
# Chloride, Whole Blood              0.000860
# Creatinine                         0.000470
# Creatinine, Whole Blood            0.005613
# Eosinophils                        0.009268
# Ferritin                           0.007780
# Free Calcium                       0.000767
# Glucose                            0.000277
# Hemoglobin                         0.002131
# High-Sensitivity CRP               0.047619
# INR(PT)                            0.008324
# Lactate                            0.000448
# Lactate Dehydrogenase (LD)         0.000253
# Lymphocytes                        0.009260
# Lymphocytes, Percent               0.000798
# Magnesium                          0.000168
# Monocytes                          0.009260
# Neutrophils                        0.009275
# Oxygen Saturation                  0.000825
# PT                                 0.008135
# PTT                                0.010231
# Phosphate                          0.000119
# Platelet Count                     0.004199
# Potassium                          0.000539
# Potassium, Whole Blood             0.000787
# Protein, Total                     0.000279
# Sedimentation Rate                 0.014348
# Sodium                             0.000137
# Sodium, Whole Blood                0.000404
# Troponin T                         0.440183
# Urea Nitrogen                      0.000704
# WBC Count                          0.000798
# pCO2                               0.000999
# pH                                 0.000492
# pO2                                0.000509
# Name: valuenum, dtype: float64

# %% [markdown]
# ### parse comment

# %%
# this is now essentially a mapping table
dist.head()
# Out:
#                          lab_name  \
# 0                      Troponin T
# 1                      Troponin T
# 2                Bilirubin, Total
# 3  Alanine Aminotransferase (ALT)
# 4                             PTT
#
#                                           comments  count
# 0  <0.01.  CTROPNT > 0.10 NG/ML SUGGESTS ACUTE MI.  66054
# 1  <0.01.  cTropnT > 0.10 ng/mL suggests Acute MI.  40239
# 2                                            <0.2.  14789
# 3                                              <5.   8817
# 4                                UNABLE TO REPORT.   6814

# %%
def _parse_labs_comment(comment: str) -> float:
    '''
    Use regular expression to parse the comment and extract the numeric value.
    '''
    match = re.search(r'\d+\.\d+|\d+', comment)
    parsed_number = float(match.group()) if match else np.nan
    comment_lower = comment.lower()
    if "ptt" in comment_lower and "unable" in comment_lower:
        return parsed_number
    # if any part of the comment contains "not done" or "unable to report" (case insensitive), return NA
    if "not done" in comment_lower or "unable" in comment_lower:
        return np.nan    
    return parsed_number

# %%
# test cases
comment_parser_tests = {
    "UNABLE TO REPORT.": np.nan,
    "NOT DONE.": np.nan,
    "GREATER THAN 300.  LOW RISK <1.0, AVERAGE RISK 1.0-3.0, HIGH RISK >3.0 (BUT <10).": 300.0,
    "LESS THAN 0.01.  CTROPNT > 0.10 NG/ML SUGGESTS ACUTE MI.": 0.01,
    "<0.01.  CTROPNT > 0.10 NG/ML SUGGESTS ACUTE MI.": 0.01,
    "<5.": 5.0,
    "<0.2.": 0.2,
    "ND .  Not Done, WBC <=0.1.": np.nan,
    "UNABLE TO REPORT. PTT < 20.": 20.0
}

def _test_parse_labs_comment(comment: str, expected: float) -> bool:
    actual = _parse_labs_comment(comment)
    if np.isnan(expected):
        return np.isnan(actual)
    return np.equal(actual, expected)

for comment, expected in comment_parser_tests.items():
    # print(f"Testing if {comment} returns {expected}...")
    actual = _parse_labs_comment(comment)
    # print(f"Actual: {actual}")
    assert _test_parse_labs_comment(comment, expected), f"Test failed for comment: {comment}"

# %% [markdown]
# Now let's try applying the new helper function to clean up the field. This function should only be applied if `valuenum` is NA.

# %%
# for some reason the following two alternatives are so much slower
df_le['valuenum'].fillna(
    df_le['comments'].map(lambda x: _parse_labs_comment(x) if pd.notna(x) else np.nan),
    inplace=True
)

df_le['valuenum'] = df_le['valuenum'].mask(
    df_le['valuenum'].isna(),
    df_le['comments'].map(lambda x: _parse_labs_comment(x) if pd.notna(x) else np.nan)
)
# Out:
# /var/folders/yc/t9yjml6j0jn7hyvbns2vqc7m0000gp/T/ipykernel_51425/3135813706.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_le['valuenum'].fillna(

# %%
df_le: pd.DataFrame = le_labs_translated
mask = df_le["valuenum"].isna()
df_le.loc[mask, ["valuenum"]] = df_le.loc[mask, "comments"].map(
    lambda x: _parse_labs_comment(x) if pd.notna(x) else np.nan)

df_le.loc[mask, ["value"]] = df_le.loc[mask, "comments"]

# %%
df_le.head()
# Out:
#    labevent_id  subject_id   hadm_id  specimen_id  itemid order_provider_id  \
# 0       373283    10023274  25335412     18902407   51146              <NA>
# 1       373284    10023274  25335412     18902407   51200              <NA>
# 2       373286    10023274  25335412     18902407   51222              <NA>
# 3       373287    10023274  25335412     18902407   51244              <NA>
# 4       373291    10023274  25335412     18902407   51254              <NA>
#
#             charttime           storetime value  valuenum valueuom  \
# 0 2155-01-08 21:21:00 2155-01-08 21:52:00   0.4       0.4        %
# 1 2155-01-08 21:21:00 2155-01-08 21:52:00   0.2       0.2        %
# 2 2155-01-08 21:21:00 2155-01-08 21:52:00  13.6      13.6     g/dL
# 3 2155-01-08 21:21:00 2155-01-08 21:52:00  21.1      21.1        %
# 4 2155-01-08 21:21:00 2155-01-08 21:52:00   7.8       7.8        %
#
#    ref_range_lower  ref_range_upper      flag priority comments     lab_name  \
# 0              0.0              1.0      <NA>     STAT     <NA>    Basophils
# 1              1.0              7.0  abnormal     STAT     <NA>  Eosinophils
# 2             13.7             17.5  abnormal     STAT     <NA>   Hemoglobin
# 3             19.0             53.0      <NA>     STAT     <NA>  Lymphocytes
# 4              5.0             13.0      <NA>     STAT     <NA>    Monocytes
#
#           lab_category  value_parsed
# 0    basophils_percent           NaN
# 1  eosinophils_percent           NaN
# 2           hemoglobin           NaN
# 3  lymphocytes_percent           NaN
# 4    monocytes_percent           NaN

# %%
# check how many NA valuenum remain
print(f"{mask.sum()} ({mask.mean()*100:.1f}%) rows have NaN for `valuenum`")
na_valuenum: pd.DataFrame = df_le[mask]
na_valuenum.head()
# Out:
# 80213 (0.2%) rows have NaN for `valuenum`
#        labevent_id  subject_id   hadm_id  specimen_id  itemid  \
# 1292        376942    10023486  29094622     16887471   50931
# 7783        127271    10007818  22987108     92793433   51222
# 12889       501738    10031687  25318200     74977526   50893
# 12890       501739    10031687  25318200     74977526   50902
# 12892       501741    10031687  25318200     74977526   50931
#
#       order_provider_id           charttime           storetime  \
# 1292               <NA> 2154-06-30 03:22:00 2154-06-30 11:41:00
# 7783               <NA> 2146-07-12 03:10:00 2146-07-12 04:55:00
# 12889              <NA> 2141-07-06 09:35:00 2141-07-06 11:21:00
# 12890              <NA> 2141-07-06 09:35:00 2141-07-06 11:21:00
# 12892              <NA> 2141-07-06 09:35:00 2141-07-06 11:21:00
#
#                    value  valuenum valueuom  ref_range_lower  ref_range_upper  \
# 1292                 ___      <NA>    mg/dL             70.0            100.0
# 7783   UNABLE TO REPORT.      <NA>     g/dL             13.7             17.5
# 12889                ___      <NA>    mg/dL              8.4             10.3
# 12890                ___      <NA>    mEq/L             96.0            108.0
# 12892                ___      <NA>    mg/dL             70.0            100.0
#
#            flag priority           comments        lab_name   lab_category  \
# 1292   abnormal     STAT                ___         Glucose  glucose_serum
# 7783       <NA>     STAT  UNABLE TO REPORT.      Hemoglobin     hemoglobin
# 12889      <NA>     STAT                ___  Calcium, Total  calcium_total
# 12890      <NA>     STAT                ___        Chloride       chloride
# 12892      <NA>     STAT                ___         Glucose  glucose_serum
#
#        value_parsed
# 1292            NaN
# 7783            NaN
# 12889           NaN
# 12890           NaN
# 12892           NaN

# %%
na_valuenum.value_counts('comments').to_frame().reset_index().head(40)
# Out:
#                                              comments  count
# 0                                                 ___  32883
# 1                                   UNABLE TO REPORT.  24343
# 2                                           NOT DONE.  11987
# 3                          ND .  Not Done, WBC <=0.1.   7974
# 4                           UNABLE TO REPORT CLOTTED.    325
# 5                                   UNABLE TO RESULT.    287
# 6                                  UNABLE TO PERFORM.    275
# 7                    UNABLE TO REPORT.  SPECIMEN QNS.    189
# 8   UNABLE TO REPORT.  Platelet clumps, blue top t...    188
# 9                UNABLE TO REPORT.  SPECIMEN CLOTTED.    144
# 10                            UNABLE TO REPORT.  QNS.    132
# 11                    UNABLE TO REPORT, SPECIMEN QNS.    113
# 12              UNABLE TO REPORT.   SPECIMEN CLOTTED.    107
# 13                   UNABLE.  UNABLE TO PERFORM TEST.    105
# 14                UNABLE TO REPORT.  PTT <20 SECONDS.     76
# 15                                               QNS.     76
# 16    UNABLE TO REPORT.  PTT IS LESS THAN 20 SECONDS.     71
# 17                              UNABLE TO REPORT QNS.     63
# 18                        UNABLE TO REPORT.  CLOTTED.     61
# 19                UNABLE TO REPORT, SPECIMEN CLOTTED.     55
# 20               UNABLE TO REPORT.  CLOTTED SPECIMEN.     46
# 21                  UNABLE TO REPORT, CLOTTED SAMPLE.     46
# 22                         UNABLE.  UNABLE TO REPORT.     45
# 23                                 UNABLE TO REPORT .     45
# 24  UNABLE TO REPORT.  PTT < 20.0 SECONDS.  NO CLO...     43
# 25           UNABLE TO REPORT DUE TO PLATELET CLUMPS.     40
# 26                        UNABLE TO REPORT.  PTT QNS.     39
# 27                UNABLE TO REPORT DUE TO PLT CLUMPS.     39
# 28                             UNABLE TO REPORT, QNS.     37
# 29                        UNABLE TO REPORT.  PTT <20.     36
# 30               UNABLE TO REPORT.  APTT <20 SECONDS.     34
# 31                                             ERROR.     29
# 32                UNABLE TO REPORT, APTT <20 SECONDS.     27
# 33                  UNABLE TO REPORT.   SPECIMEN QNS.     26
# 34                       UNABLE TO REPORT.  PTT < 20.     25
# 35                                  UANBLE TO REPORT.     24
# 36                        UNABLE TO REPORT.  INR QNS.     22
# 37                    UNABLE TO REPORT.  PTT CLOTTED.     22
# 38                            UNABLE TO PERFORM TEST.     21
# 39        UNABLE TO REPORT.  QUANTITY NOT SUFFICIENT.     20

# %% [markdown]
# ### parse the string-based value column

# %%
mask =pd.to_numeric(df_le['value'], errors='coerce').isna()
string_only_rows = df_le[mask]

# %%
string_only_rows
# Out:
#           labevent_id  subject_id   hadm_id  specimen_id  itemid  \
# 11             373308    10023274  25335412     61097845   51003
# 16             373317    10023274  25335412     99549918   50931
# 20             373324    10023274  25335412     99549918   50983
# 30             373339    10023274  25335412     93866128   50931
# 34             373345    10023274  25335412     93866128   50983
# ...               ...         ...       ...          ...     ...
# 44335787    157197006    19887349  26179448     51727684   50931
# 44335791    157197012    19887349  26179448     51727684   50983
# 44335793    157197015    19887349  26179448     75115505   50813
# 44335798    157197021    19887349  26179448     42100292   50931
# 44335802    157197027    19887349  26179448     42100292   50983
#
#          order_provider_id           charttime           storetime  \
# 11                    <NA> 2155-01-08 21:21:00 2155-01-08 22:17:00
# 16                    <NA> 2155-01-08 21:21:00 2155-01-08 22:21:00
# 20                    <NA> 2155-01-08 21:21:00 2155-01-08 22:21:00
# 30                    <NA> 2155-01-09 06:55:00 2155-01-09 09:06:00
# 34                    <NA> 2155-01-09 06:55:00 2155-01-09 09:06:00
# ...                    ...                 ...                 ...
# 44335787              <NA> 2176-05-10 06:05:00 2176-05-10 07:10:00
# 44335791              <NA> 2176-05-10 06:05:00 2176-05-10 07:10:00
# 44335793              <NA> 2176-05-10 06:25:00 2176-05-10 06:27:00
# 44335798              <NA> 2176-05-11 06:05:00 2176-05-11 06:59:00
# 44335802              <NA> 2176-05-11 06:05:00 2176-05-11 06:59:00
#
#                                                     value  valuenum valueuom  \
# 11        <0.01.  cTropnT > 0.10 ng/mL suggests Acute MI.      0.01    ng/mL
# 16                                                    ___     117.0    mg/dL
# 20                                                    ___     138.0    mEq/L
# 30                                                    ___      98.0    mg/dL
# 34                                                    ___     137.0    mEq/L
# ...                                                   ...       ...      ...
# 44335787                                              ___     182.0    mg/dL
# 44335791                                              ___     139.0    mEq/L
# 44335793                                              ___       1.4   mmol/L
# 44335798                                              ___     157.0    mg/dL
# 44335802                                              ___     143.0    mEq/L
#
#           ref_range_lower  ref_range_upper      flag priority  \
# 11                    0.0             0.01      <NA>     STAT
# 16                   70.0            100.0  abnormal     STAT
# 20                  135.0            147.0      <NA>     STAT
# 30                   70.0            100.0      <NA>  ROUTINE
# 34                  135.0            147.0      <NA>  ROUTINE
# ...                   ...              ...       ...      ...
# 44335787             70.0            100.0  abnormal     STAT
# 44335791            135.0            147.0      <NA>     STAT
# 44335793              0.5              2.0      <NA>     <NA>
# 44335798             70.0            100.0  abnormal     STAT
# 44335802            135.0            147.0      <NA>     STAT
#
#                                                    comments    lab_name  \
# 11          <0.01.  cTropnT > 0.10 ng/mL suggests Acute MI.  Troponin T
# 16        If fasting, 70-100 normal, >125 provisional di...     Glucose
# 20                           New reference range as of ___.      Sodium
# 30        If fasting, 70-100 normal, >125 provisional di...     Glucose
# 34                           New reference range as of ___.      Sodium
# ...                                                     ...         ...
# 44335787  If fasting, 70-100 normal, >125 provisional di...     Glucose
# 44335791                     New reference range as of ___.      Sodium
# 44335793                                GREEN TOP P.VENOUS.     Lactate
# 44335798  If fasting, 70-100 normal, >125 provisional di...     Glucose
# 44335802                     New reference range as of ___.      Sodium
#
#            lab_category  value_parsed
# 11           troponin_t          0.01
# 16        glucose_serum           NaN
# 20               sodium           NaN
# 30        glucose_serum           NaN
# 34               sodium           NaN
# ...                 ...           ...
# 44335787  glucose_serum           NaN
# 44335791         sodium           NaN
# 44335793        lactate           NaN
# 44335798  glucose_serum           NaN
# 44335802         sodium           NaN
#
# [4109008 rows x 19 columns]

# %% [markdown]
# ### add comment as non-numeric lab value

# %%
df_le['value'] = df_le['value'].fillna(df_le['comments'])

# %%
df_le
# Out:
#           labevent_id  subject_id   hadm_id  specimen_id  itemid  \
# 0              373283    10023274  25335412     18902407   51146
# 1              373284    10023274  25335412     18902407   51200
# 2              373286    10023274  25335412     18902407   51222
# 3              373287    10023274  25335412     18902407   51244
# 4              373291    10023274  25335412     18902407   51254
# ...               ...         ...       ...          ...     ...
# 44335800    157197025    19887349  26179448     42100292   50970
# 44335801    157197026    19887349  26179448     42100292   50971
# 44335802    157197027    19887349  26179448     42100292   50983
# 44335803    157197028    19887349  26179448     42100292   51006
# 44335804    132527854    18354631  27930485     76653575   51265
#
#          order_provider_id           charttime           storetime value  \
# 0                     <NA> 2155-01-08 21:21:00 2155-01-08 21:52:00   0.4
# 1                     <NA> 2155-01-08 21:21:00 2155-01-08 21:52:00   0.2
# 2                     <NA> 2155-01-08 21:21:00 2155-01-08 21:52:00  13.6
# 3                     <NA> 2155-01-08 21:21:00 2155-01-08 21:52:00  21.1
# 4                     <NA> 2155-01-08 21:21:00 2155-01-08 21:52:00   7.8
# ...                    ...                 ...                 ...   ...
# 44335800              <NA> 2176-05-11 06:05:00 2176-05-11 06:59:00   4.1
# 44335801              <NA> 2176-05-11 06:05:00 2176-05-11 06:59:00   3.6
# 44335802              <NA> 2176-05-11 06:05:00 2176-05-11 06:59:00   ___
# 44335803              <NA> 2176-05-11 06:05:00 2176-05-11 06:59:00     5
# 44335804              <NA> 2178-05-16 04:20:00 2178-05-16 05:00:00   432
#
#           valuenum valueuom  ref_range_lower  ref_range_upper      flag  \
# 0              0.4        %              0.0              1.0      <NA>
# 1              0.2        %              1.0              7.0  abnormal
# 2             13.6     g/dL             13.7             17.5  abnormal
# 3             21.1        %             19.0             53.0      <NA>
# 4              7.8        %              5.0             13.0      <NA>
# ...            ...      ...              ...              ...       ...
# 44335800       4.1    mg/dL              2.7              4.5      <NA>
# 44335801       3.6    mEq/L              3.3              5.1      <NA>
# 44335802     143.0    mEq/L            135.0            147.0      <NA>
# 44335803       5.0    mg/dL              6.0             20.0  abnormal
# 44335804     432.0     K/uL            150.0            400.0  abnormal
#
#          priority                        comments        lab_name  \
# 0            STAT                            <NA>       Basophils
# 1            STAT                            <NA>     Eosinophils
# 2            STAT                            <NA>      Hemoglobin
# 3            STAT                            <NA>     Lymphocytes
# 4            STAT                            <NA>       Monocytes
# ...           ...                             ...             ...
# 44335800     STAT                            <NA>       Phosphate
# 44335801     STAT                            <NA>       Potassium
# 44335802     STAT  New reference range as of ___.          Sodium
# 44335803     STAT                            <NA>   Urea Nitrogen
# 44335804     STAT                            <NA>  Platelet Count
#
#                  lab_category  value_parsed
# 0           basophils_percent           NaN
# 1         eosinophils_percent           NaN
# 2                  hemoglobin           NaN
# 3         lymphocytes_percent           NaN
# 4           monocytes_percent           NaN
# ...                       ...           ...
# 44335800            phosphate           NaN
# 44335801            potassium           NaN
# 44335802               sodium           NaN
# 44335803                  bun           NaN
# 44335804       platelet_count           NaN
#
# [44335805 rows x 19 columns]

# %% [markdown]
# # Validate

# %%
clif_labs = read_from_rclif("labs")

# %%
clif_labs

# %%
results = dr.execute(["le_labs_translated", "le_labs_comments_parsed"])
le_labs_translated: pd.DataFrame = results['le_labs_translated']
le_labs_comments_parsed: pd.DataFrame = results['le_labs_comments_parsed']

# %%
le_labs_comments_parsed
