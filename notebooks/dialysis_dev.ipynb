# %% [markdown]
# # Init

# %%
cd ..
# Out:
# /Users/wliao0504/code/clif/CLIF-MIMIC
# /Users/wliao0504/code/clif/CLIF-MIMIC/.venv/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
pwd
# Out:
# '/Users/wliao0504/code/clif/CLIF-MIMIC'

# %%
# src/tables/patient_assessments.py
import numpy as np
import pandas as pd
import logging
import duckdb
import pandera as pa
from importlib import reload
import src.utils as utils
from typing import Dict, List
# reload(utils)
from src.utils import construct_mapper_dict, fetch_mimic_events, load_mapping_csv, \
    get_relevant_item_ids, find_duplicates, rename_and_reorder_cols, save_to_rclif, \
    convert_and_sort_datetime, setup_logging, con, REPO_ROOT, mimic_table_pathfinder, \
    search_mimic_items
from src.utils_qa import all_null_check

# %% [markdown]
# # Utils

# %%
CLIF_CRRT_SCHEMA = pa.DataFrameSchema(
    {
        "hospitalization_id": pa.Column(str, nullable=False),
        "recorded_dttm": pa.Column(pd.DatetimeTZDtype(unit="us", tz="UTC"), nullable=False),
        "crrt_mode_name": pa.Column(str, checks=[all_null_check], nullable=True),
        "crrt_mode_category": pa.Column(str, checks=[all_null_check], nullable=True),
        "dialysis_machine_name": pa.Column(str, checks=[all_null_check], nullable=True),
        "blood_flow_rate": pa.Column(float, nullable=True),
        "pre_filter_replacement_fluid_rate": pa.Column(float, nullable=True),
        "post_filter_replacement_fluid_rate": pa.Column(float, nullable=True),
        "dialysate_flow_rate": pa.Column(float, nullable=True),
        "ultrafiltration_out": pa.Column(float, nullable=True),
    },  
    strict=True,
)

CRRT_COLUMNS: List[str] = list(CLIF_CRRT_SCHEMA.columns.keys())

# %% [markdown]
# # Dev

# %%
dialysis_mapping = load_mapping_csv("dialysis")
dialysis_mapping.head()
# Out:
#          clif_variable         table  itemid                         label  \
# 0                  NaN           NaN  224146              System Integrity
# 1  ultrafiltration_out  crrt_therapy  226457          Ultrafiltrate Output
# 2                  NaN           NaN  224191  Hourly Patient Fluid Removal
# 3                  NaN           NaN  224149               Access Pressure
# 4                  NaN           NaN  224150               Filter Pressure
#
#            abbreviation      linksto  category unitname param_type   count  \
# 0      System Integrity  chartevents  Dialysis      NaN       Text  241835
# 1  Ultrafiltrate Output  chartevents  Dialysis       mL    Numeric  217653
# 2            Hourly PFR  chartevents  Dialysis       mL    Numeric  209426
# 3       Access Pressure  chartevents  Dialysis     mmHg    Numeric  206268
# 4       Filter Pressure  chartevents  Dialysis     mmHg    Numeric  206263
#
#                                      value_instances  Unnamed: 11 Unnamed: 12  \
# 0  {'Active': 176983, 'Clots Present': 43537, 'Ne...          NaN         NaN
# 1            Max: 16800.0, Min: -600.0, Mean: 365.13          NaN         NaN
# 2           Max: 150179.0, Min: -950.0, Mean: 374.84          NaN         NaN
# 3           Max: 500.0, Min: -308135.0, Mean: -52.29          NaN         NaN
# 4            Max: 60132.0, Min: -503.0, Mean: 122.07          NaN         NaN
#
#                              Unnamed: 13                       Unnamed: 14
# 0                                    NaN                               NaN
# 1  this acounts for rr in addition to dr  should be highest for H > DF > D
# 2                                    NaN                      HDF > HD > H
# 3                                    NaN                               NaN
# 4                                    NaN                               NaN

# %%
crrt_items = dialysis_mapping[dialysis_mapping["table"].astype(str).str.contains("crrt")]
crrt_items
# Out:
#                          clif_variable         table  itemid  \
# 1                  ultrafiltration_out  crrt_therapy  226457
# 8                  dialysate_flow_rate  crrt_therapy  224154
# 12                     blood_flow_rate  crrt_therapy  224144
# 13   pre_filter_replacement_fluid_rate  crrt_therapy  228005
# 14  post_filter_replacement_fluid_rate  crrt_therapy  228006
# 18                      crrt_mode_name  crrt_therapy  227290
#
#                                label                      abbreviation  \
# 1               Ultrafiltrate Output              Ultrafiltrate Output
# 8                     Dialysate Rate                    Dialysate Rate
# 12               Blood Flow (ml/min)               Blood Flow (ml/min)
# 13  PBP (Prefilter) Replacement Rate  PBP (Prefilter) Replacement Rate
# 14      Post Filter Replacement Rate      Post Filter Replacement Rate
# 18                         CRRT mode                         CRRT mode
#
#         linksto  category unitname param_type   count  \
# 1   chartevents  Dialysis       mL    Numeric  217653
# 8   chartevents  Dialysis    ml/hr    Numeric  200611
# 12  chartevents  Dialysis   ml/min    Numeric  196378
# 13  chartevents  Dialysis    ml/hr    Numeric  183428
# 14  chartevents  Dialysis    ml/hr    Numeric  179745
# 18  chartevents  Dialysis      NaN       Text  121114
#
#                                       value_instances  Unnamed: 11  \
# 1             Max: 16800.0, Min: -600.0, Mean: 365.13          NaN
# 8              Max: 1400000.0, Min: 0.0, Mean: 743.96          NaN
# 12          Max: 1801300.0, Min: -120.0, Mean: 167.79          NaN
# 13      Max: 1822540.0, Min: -601600.0, Mean: 1590.45          NaN
# 14           Max: 5000.0, Min: -35300.0, Mean: 232.86          NaN
# 18  {'CVVHDF': 116065, 'CVVHD': 2874, 'CVVH': 2113...          NaN
#
#    Unnamed: 12                            Unnamed: 13  \
# 1          NaN  this acounts for rr in addition to dr
# 8          NaN                                    NaN
# 12         NaN                                    NaN
# 13         NaN                                    NaN
# 14         NaN                                    NaN
# 18         NaN                                    NaN
#
#                          Unnamed: 14
# 1   should be highest for H > DF > D
# 8                                NaN
# 12                               NaN
# 13                               NaN
# 14                               NaN
# 18                    HDF: both rate

# %%
crrt_id_to_variable_mapper = dict(zip(crrt_items["itemid"], crrt_items["clif_variable"]))
crrt_id_to_variable_mapper
# Out:
# {226457: 'ultrafiltration_out',
#  224154: 'dialysate_flow_rate',
#  224144: 'blood_flow_rate',
#  228005: 'pre_filter_replacement_fluid_rate',
#  228006: 'post_filter_replacement_fluid_rate',
#  227290: 'crrt_mode_name'}

# %%
crrt_item_ids = crrt_items["itemid"].tolist()
crrt_item_ids
# Out:
# [226457, 224154, 224144, 228005, 228006, 227290]

# %%
crrt_events = fetch_mimic_events(crrt_item_ids)

# %%
crrt_events.head()
# Out:
#    itemid                             label   hadm_id   stay_id  \
# 0  224154                    Dialysate Rate  28317408  32824762
# 1  228005  PBP (Prefilter) Replacement Rate  28317408  32824762
# 2  228006      Post Filter Replacement Rate  28317408  32824762
# 3  224154                    Dialysate Rate  28317408  32824762
# 4  228005  PBP (Prefilter) Replacement Rate  28317408  32824762
#
#                  time value valueuom
# 0 2150-05-21 07:00:00   800    ml/hr
# 1 2150-05-21 07:00:00  1400    ml/hr
# 2 2150-05-21 07:00:00   200    ml/hr
# 3 2150-05-21 08:00:00   800    ml/hr
# 4 2150-05-21 08:00:00  1400    ml/hr

# %%
crrt_events["crrt_variable"] = crrt_events["itemid"].map(crrt_id_to_variable_mapper)
crrt_events.head()
# Out:
#    itemid                             label   hadm_id   stay_id  \
# 0  224154                    Dialysate Rate  28317408  32824762
# 1  228005  PBP (Prefilter) Replacement Rate  28317408  32824762
# 2  228006      Post Filter Replacement Rate  28317408  32824762
# 3  224154                    Dialysate Rate  28317408  32824762
# 4  228005  PBP (Prefilter) Replacement Rate  28317408  32824762
#
#                  time value valueuom                       crrt_variable
# 0 2150-05-21 07:00:00   800    ml/hr                 dialysate_flow_rate
# 1 2150-05-21 07:00:00  1400    ml/hr   pre_filter_replacement_fluid_rate
# 2 2150-05-21 07:00:00   200    ml/hr  post_filter_replacement_fluid_rate
# 3 2150-05-21 08:00:00   800    ml/hr                 dialysate_flow_rate
# 4 2150-05-21 08:00:00  1400    ml/hr   pre_filter_replacement_fluid_rate

# %%
crrt_events.value_counts(["crrt_variable", "valueuom"])
# Out:
# crrt_variable                       valueuom
# ultrafiltration_out                 mL          365849
# dialysate_flow_rate                 ml/hr       318185
# blood_flow_rate                     ml/min      313631
# pre_filter_replacement_fluid_rate   ml/hr       300423
# post_filter_replacement_fluid_rate  ml/hr       295814
# Name: count, dtype: int64

# %%
crrt_events_w = crrt_events.pivot(
    index=["hadm_id", "time"], columns=["crrt_variable"], values="value"
    ).reset_index().rename_axis(None, axis=1)

crrt_events_w.head()
# Out:
#     hadm_id                time blood_flow_rate crrt_mode_name  \
# 0  20003427 2184-05-17 01:00:00             NaN            NaN
# 1  20003427 2184-05-17 01:40:00             150            NaN
# 2  20003427 2184-05-17 02:00:00             150            NaN
# 3  20003427 2184-05-17 03:00:00             150            NaN
# 4  20003427 2184-05-17 04:00:00             150            NaN
#
#   dialysate_flow_rate post_filter_replacement_fluid_rate  \
# 0                 NaN                                NaN
# 1                 700                                200
# 2                 700                                200
# 3                 700                                200
# 4                 700                                200
#
#   pre_filter_replacement_fluid_rate ultrafiltration_out
# 0                               NaN                  66
# 1                              1600                 NaN
# 2                              1600                 471
# 3                              1600                 638
# 4                              1600                 527

# %%
crrt_events_w.value_counts("crrt_mode_name")
# Out:
# crrt_mode_name
# CVVHDF    192933
# CVVHD       5607
# CVVH        4427
# SCUF          68
# Name: count, dtype: int64

# %%
query = """
SELECT
    CAST(hadm_id as VARCHAR) as hospitalization_id,
    CAST(time as TIMESTAMP) as recorded_dttm,
    CAST(crrt_mode_name as VARCHAR) as crrt_mode_name,
    CAST(lower(crrt_mode_name) as VARCHAR) as crrt_mode_category,
    CAST(NULL as VARCHAR) as dialysis_machine_name,
    CAST(blood_flow_rate as FLOAT) * 60 as blood_flow_rate, -- convert from mL/min to mL/hr
    CAST(pre_filter_replacement_fluid_rate as FLOAT) as pre_filter_replacement_fluid_rate,
    CAST(post_filter_replacement_fluid_rate as FLOAT) as post_filter_replacement_fluid_rate,
    CAST(dialysate_flow_rate as FLOAT) as dialysate_flow_rate,
    CAST(ultrafiltration_out as FLOAT) as ultrafiltration_out
FROM crrt_events_w
"""
df = con.execute(query).df()
df.head()
# Out:
#   hospitalization_id       recorded_dttm crrt_mode_name crrt_mode_category  \
# 0           20003427 2184-05-17 01:00:00           None               None
# 1           20003427 2184-05-17 01:40:00           None               None
# 2           20003427 2184-05-17 02:00:00           None               None
# 3           20003427 2184-05-17 03:00:00           None               None
# 4           20003427 2184-05-17 04:00:00           None               None
#
#   dialysis_machine_name  blood_flow_rate  pre_filter_replacement_fluid_rate  \
# 0                  None              NaN                                NaN
# 1                  None           9000.0                             1600.0
# 2                  None           9000.0                             1600.0
# 3                  None           9000.0                             1600.0
# 4                  None           9000.0                             1600.0
#
#    post_filter_replacement_fluid_rate  dialysate_flow_rate  \
# 0                                 NaN                  NaN
# 1                               200.0                700.0
# 2                               200.0                700.0
# 3                               200.0                700.0
# 4                               200.0                700.0
#
#    ultrafiltration_out
# 0                 66.0
# 1                  NaN
# 2                471.0
# 3                638.0
# 4                527.0

# %% [markdown]
# # Validate

# %%
import src.tables.crrt_therapy as crrt_therapy
reload(crrt_therapy)

test_outcome = crrt_therapy._test()
# Out:
# {'schema_tested': True}
